# %% [markdown]
# ### This notebook goes through reviews on GoodReads using their API.  The code is looking for books with the words "data science" in the title.

# %% [markdown]
# Do not share this notebook if keys are in it
#
# Do not push the api_keys.json file to github, leave it on the local machine to keep them a secret.
#
# https://www.goodreads.com/api

# %%
pwd

# %%
import requests 
import json

# %%
#open the file on local machine with the GoodReads API key
with open('api_keys.json','r') as f:
    keys = json.loads(f.read())

# %%
#use this if you want to see what the key value is - do not print when sharing on GitHub
# keys['key']

# %%
#Set the parameters based on the API documentation
#We want to find books that have "data science" as a part of the information provided

base_url = 'https://goodreads.com'
search_domain = '/search/index.xml'

parameters = {
    'q':'data science',
    'page': 1,
    'key': keys['key']
}

# %%
#confirm the code is able to access the site

r = requests.get(base_url + search_domain, params = parameters)
r.status_code
# Out:
# 200

# %%
#view the results of the API call

r.text
# Out:
# '<?xml version="1.0" encoding="UTF-8"?>\n<GoodreadsResponse>\n  <Request>\n    <authentication>true</authentication>\n      <key><![CDATA[ka4Fs642Xr9prKBGBraoSw]]></key>\n    <method><![CDATA[search_index]]></method>\n  </Request>\n  <search>\n  <query><![CDATA[data science]]></query>\n    <results-start>1</results-start>\n    <results-end>20</results-end>\n    <total-results>2114</total-results>\n    <source>Goodreads</source>\n    <query-time-seconds>0.20</query-time-seconds>\n    <results>\n        <work>\n  <id type="integer">24087179</id>\n  <books_count type="integer">9</books_count>\n  <ratings_count type="integer">436</ratings_count>\n  <text_reviews_count type="integer">43</text_reviews_count>\n  <original_publication_year type="integer">2013</original_publication_year>\n  <original_publication_month type="integer">1</original_publication_month>\n  <original_publication_day type="integer">1</original_publication_day>\n  <average_rating>3.74</average_rating>\n  <best_book type="Book">\n    <id type="integer">17346997</id>\n    <title>Doing Data Science</title>\n    <author>\n      <id type="integer">5930481</id>\n      <name>Rachel Schutt</name>\n    </author>\n    <image_url>https://images.gr-assets.com/books/1411927798m/17346997.jpg</image_url>\n    <small_image_url>https://images.gr-assets.com/books/1411927798s/17346997.jpg</small_image_url>\n  </best_book>\n</work>\n\n        <work>\n  <id type="integer">24982572</id>\n  <books_count type="integer">9</books_count>\n  <ratings_count type="integer">752</ratings_count>\n  <text_reviews_count type="integer">44</text_reviews_count>\n  <original_publication_year type="integer">2013</original_publication_year>\n  <original_publication_month type="integer">10</original_publication_month>\n  <original_publication_day type="integer">31</original_publication_day>\n  <average_rating>4.17</average_rating>\n  <best_book type="Book">\n    <id type="integer">17682206</id>\n    <title>Data Smart: Using Data Science to Transform Information into Insight</title>\n    <author>\n      <id type="integer">7445541</id>\n      <name>John W. Foreman</name>\n    </author>\n    <image_url>https://images.gr-assets.com/books/1540820090m/17682206.jpg</image_url>\n    <small_image_url>https://images.gr-assets.com/books/1540820090s/17682206.jpg</small_image_url>\n  </best_book>\n</work>\n\n        <work>\n  <id type="integer">45161385</id>\n  <books_count type="integer">11</books_count>\n  <ratings_count type="integer">541</ratings_count>\n  <text_reviews_count type="integer">45</text_reviews_count>\n  <original_publication_year type="integer">2015</original_publication_year>\n  <original_publication_month type="integer">4</original_publication_month>\n  <original_publication_day type="integer">14</original_publication_day>\n  <average_rating>3.91</average_rating>\n  <best_book type="Book">\n    <id type="integer">25407018</id>\n    <title>Data Science from Scratch: First Principles with Python</title>\n    <author>\n      <id type="integer">2966563</id>\n      <name>Joel Grus</name>\n    </author>\n    <image_url>https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png</image_url>\n    <small_image_url>https://s.gr-assets.com/assets/nophoto/book/50x75-a91bf249278a81aabab721ef782c4a74.png</small_image_url>\n  </best_book>\n</work>\n\n        <work>\n  <id type="integer">44680072</id>\n  <books_count type="integer">12</books_count>\n  <ratings_count type="integer">108</ratings_count>\n  <text_reviews_count type="integer">11</text_reviews_count>\n  <original_publication_year type="integer">2014</original_publication_year>\n  <original_publication_month type="integer">5</original_publication_month>\n  <original_publication_day type="integer">19</original_publication_day>\n  <average_rating>3.42</average_rating>\n  <best_book type="Book">\n    <id type="integer">25008399</id>\n    <title>Data Science For Dummies</title>\n    <author>\n      <id type="integer">8096344</i ...

# %%
import xmltodict

# %% [markdown]
# Review the results of the API call
# - Convert to dictionary
# - drill down into the dictionary to find the keys of the data we are looking for

# %%
results = xmltodict.parse(r.text)
results
# Out:
# OrderedDict([('GoodreadsResponse',
#               OrderedDict([('Request',
#                             OrderedDict([('authentication', 'true'),
#                                          ('key', 'ka4Fs642Xr9prKBGBraoSw'),
#                                          ('method', 'search_index')])),
#                            ('search',
#                             OrderedDict([('query', 'data science'),
#                                          ('results-start', '1'),
#                                          ('results-end', '20'),
#                                          ('total-results', '2114'),
#                                          ('source', 'Goodreads'),
#                                          ('query-time-seconds', '0.20'),
#                                          ('results',
#                                           OrderedDict([('work',
#                                                         [OrderedDict([('id',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '24087179')])),
#                                                                       ('books_count',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '9')])),
#                                                                       ('ratings_count',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '436')])),
#                                                                       ('text_reviews_count',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '43')])),
#                                                                       ('original_publication_year',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '2013')])),
#                                                                       ('original_publication_month',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '1')])),
#                                                                       ('original_publication_day',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '1')])),
#                                                                       ('average_rating',
#                                                                        '3.74'),
#                                                                       ('best_book',
#                                                                        OrderedDict([('@type',
#                                                                                      'Book'),
#                                                                                     ('id',
#                                                                                      OrderedDict([('@type',
#                                                                                                    'integer'),
#                                                                                                   ('#text',
#                                                                                                    '17346997')])),
#                                                                                     ('title',
#                                                                                      'Doing Data Science'),
#                                                                                     ('author',
#                                                                                      OrderedDict([('id',
#                                                                                                    OrderedDict([('@type',
#                                                                                                                  'integer'),
#                                                                                                                 ('#text',
#                                                                                                                  '5930481')])),
#                                                                                                   ('name',
#                                                                                                    'Rachel Schutt')])),
#                                                                                     ('image_url',
#                                                                                      'https://images.gr-assets.com/books/1411927798m/17346997.jpg'),
#                                                                                     ('small_image_url',
#                                                                                      'https://images.gr-assets.com/books/1411927798s/17346997.jpg')]))]),
#                                                          OrderedDict([('id',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '24982572')])),
#                                                                       ('books_count',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '9')])),
#                                                                       ('ratings_count',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '752')])),
#                                                                       ('text_reviews_count',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '44')])),
#                                                                       ('original_publication_year',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '2013')])),
#                                                                       ('original_publication_month',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '10')])),
#                                                                       ('original_publication_day',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '31')])),
#                                                                       ('average_rating',
#                                                                        '4.17'),
#                                                                       ('best_book',
#                                                                        OrderedDict([('@type',
#                                                                                      'Book'),
#                                                                                     ('id',
#                                                                                      OrderedDict([('@type',
#                                                                                                    'integer'),
#                                                                                                   ('#text',
#                                                                                                    '17682206')])),
#                                                                                     ('title',
#                                                                                      'Data Smart: Using Data Science to Transform Information into Insight'),
#                                                                                     ('author',
#                                                                                      OrderedDict([('id',
#                                                                                                    OrderedDict([('@type',
#                                                                                                                  'integer'),
#                                                                                                                 ('#text',
#                                                                                                                  '7445541')])),
#                                                                                                   ('name',
#                                                                                                    'John W. Foreman')])),
#                                                                                     ('image_url',
#                                                                                      'https://images.gr-assets.com/books/1540820090m/17682206.jpg'),
#                                                                                     ('small_image_url',
#                                                                                      'https://images.gr-assets.com/books/1540820090s/17682206.jpg')]))]),
#                                                          OrderedDict([('id',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '45161385')])),
#                                                                       ('books_count',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '11')])),
#                                                                       ('ratings_count',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '541')])),
#                                                                       ('text_reviews_count',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '45')])),
#                                                                       ('original_publication_year',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '2015')])),
#                                                                       ('original_publication_month',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '4')])),
#                                                                       ('original_publication_day',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '14')])),
#                                                                       ('average_rating',
#                                                                        '3.91'),
#                                                                       ('best_book',
#                                                                        OrderedDict([('@type',
#                                                                                      'Book'),
#                                                                                     ('id',
#                                                                                      OrderedDict([('@type',
#                                                                                                    'integer'),
#                                                                                                   ('#text',
#                                                                                                    '25407018')])),
#                                                                                     ('title',
#                                                                                      'Data Science from Scratch: First Principles with Python'),
#                                                                                     ('author',
#                                                                                      OrderedDict([('id',
#                                                                                                    OrderedDict([('@type',
#                                                                                                                  'integer'),
#                                                                                                                 ('#text',
#                                                                                                                  '2966563')])),
#                                                                                                   ('name',
#                                                                                                    'Joel Grus')])),
#                                                                                     ('image_url',
#                                                                                      'https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png'),
#                                                                                     ('small_image_url',
#                                                                                      'https://s.gr-assets.com/assets/nophoto/book/50x75-a91bf249278a81aabab721ef782c4a74.png')]))]),
#                                                          OrderedDict([('id',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '44680072')])),
#                                                                       ('books_count',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '12')])),
#                                                                       ('ratings_count',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '108')])),
#                                                                       ('text_reviews_count',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '11')])),
#                                                                       ('original_publication_year',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '2014')])),
#                                                                       ('original_publication_month',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '5')])),
#                                                                       ('original_publication_day',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '19')])),
#                                                                       ('average_rating',
#                                                                        '3.42'),
#                                                                       ('best_book',
#                                                                        OrderedDict([('@type',
#                                                                                      'Book'),
#                                                                                     ('id',
#                                                                                      OrderedDict([('@type',
#                                                                                                    'integer'),
#                                                                                                   ('#text',
#                                                                                                    '25008399')])),
#                                                                                     ('title',
#                                                                                      'Data Science For Dummies'),
#                                                                                     ('author',
#                                                                                      OrderedDict([('id',
#                                                                                                    OrderedDict([('@type',
#                                                                                                                  'integer'),
#                                                                                                                 ('#text',
#                                                                                                                  '8096344')])),
#                                                                                                   ('name',
#                                                                                                    'Lillian Pierson')])),
#                                                                                     ('image_url',
#                                                                                      'https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png'),
#                                                                                     ('small_image_url',
#                                                                                      'https://s.gr-assets.com/assets/nophoto/book/50x75-a91bf249278a81aabab721ef782c4a74.png')]))]),
#                                                          OrderedDict([('id',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '58519365')])),
#                                                                       ('books_count',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '4')])),
#                                                                       ('ratings_count',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '114')])),
#                                                                       ('text_reviews_count',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '14')])),
#                                                                       ('original_publication_year',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('@nil',
#                                                                                      'true')])),
#                                                                       ('original_publication_month',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('@nil',
#                                                                                      'true')])),
#                                                                       ('original_publication_day',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('@nil',
#                                                                                      'true')])),
#                                                                       ('average_rating',
#                                                                        '3.82'),
#                                                                       ('best_book',
#                                                                        OrderedDict([('@type',
#                                                                                      'Book'),
#                                                                                     ('id',
#                                                                                      OrderedDict([('@type',
#                                                                                                    'integer'),
#                                                                                                   ('#text',
#                                                                                                    '36722689')])),
#                                                                                     ('title',
#                                                                                      'Data Science'),
#                                                                                     ('author',
#                                                                                      OrderedDict([('id',
#                                                                                                    OrderedDict([('@type',
#                                                                                                                  'integer'),
#                                                                                                                 ('#text',
#                                                                                                                  '1794190')])),
#                                                                                                   ('name',
#                                                                                                    'John D. Kelleher')])),
#                                                                                     ('image_url',
#                                                                                      'https://images.gr-assets.com/books/1514420265m/36722689.jpg'),
#                                                                                     ('small_image_url',
#                                                                                      'https://images.gr-assets.com/books/1514420265s/36722689.jpg')]))]),
#                                                          OrderedDict([('id',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '17831806')])),
#                                                                       ('books_count',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '5')])),
#                                                                       ('ratings_count',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '259')])),
#                                                                       ('text_reviews_count',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '12')])),
#                                                                       ('original_publication_year',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '2011')])),
#                                                                       ('original_publication_month',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '9')])),
#                                                                       ('original_publication_day',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '15')])),
#                                                                       ('average_rating',
#                                                                        '3.65'),
#                                                                       ('best_book',
#                                                                        OrderedDict([('@type',
#                                                                                      'Book'),
#                                                                                     ('id',
#                                                                                      OrderedDict([('@type',
#                                                                                                    'integer'),
#                                                                                                   ('#text',
#                                                                                                    '12700492')])),
#                                                                                     ('title',
#                                                                                      'Building Data Science Teams'),
#                                                                                     ('author',
#                                                                                      OrderedDict([('id',
#                                                                                                    OrderedDict([('@type',
#                                                                                                                  'integer'),
#                                                                                                                 ('#text',
#                                                                                                                  '5227216')])),
#                                                                                                   ('name',
#                                                                                                    'D.J. Patil')])),
#                                                                                     ('image_url',
#                                                                                      'https://images.gr-assets.com/books/1354249859m/12700492.jpg'),
#                                                                                     ('small_image_url',
#                                                                                      'https://images.gr-assets.com/books/1354249859s/12700492.jpg')]))]),
#                                                          OrderedDict([('id',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '25100684')])),
#                                                                       ('books_count',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '10')])),
#                                                                       ('ratings_count',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '1292')])),
#                                                                       ('text_reviews_count',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '86')])),
#                                                                       ('original_publication_year',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '2013')])),
#                                                                       ('original_publication_month',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '1')])),
#                                                                       ('original_publication_day',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '1')])),
#                                                                       ('average_rating',
#                                                                        '4.17'),
#                                                                       ('best_book',
#                                                                        OrderedDict([('@type',
#                                                                                      'Book'),
#                                                                                     ('id',
#                                                                                      OrderedDict([('@type',
#                                                                                                    'integer'),
#                                                                                                   ('#text',
#                                                                                                    '17912916')])),
#                                                                                     ('title',
#                                                                                      'Data Science for Business: What you need to know about data mining and data-analytic thinking'),
#                                                                                     ('author',
#                                                                                      OrderedDict([('id',
#                                                                                                    OrderedDict([('@type',
#                                                                                                                  'integer'),
#                                                                                                                 ('#text',
#                                                                                                                  '891152')])),
#                                                                                                   ('name',
#                                                                                                    'Foster Provost')])),
#                                                                                     ('image_url',
#                                                                                      'https://images.gr-assets.com/books/1374654260m/17912916.jpg'),
#                                                                                     ('small_image_url',
#                                                                                      'https://images.gr-assets.com/books/1374654260s/17912916.jpg')]))]),
#                                                          OrderedDict([('id',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '19251618')])),
#                                                                       ('books_count',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '7')])),
#                                                                       ('ratings_count',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '471')])),
#                                                                       ('text_reviews_count',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '30')])),
#                                                                       ('original_publication_year',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '2011')])),
#                                                                       ('original_publication_month',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '4')])),
#                                                                       ('original_publication_day',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '1')])),
#                                                                       ('average_rating',
#                                                                        '3.66'),
#                                                                       ('best_book',
#                                                                        OrderedDict([('@type',
#                                                                                      'Book'),
#                                                                                     ('id',
#                                                                                      OrderedDict([('@type',
#                                                                                                    'integer'),
#                                                                                                   ('#text',
#                                                                                                    '13638556')])),
#                                                                                     ('title',
#                                                                                      'What Is Data Science?'),
#                                                                                     ('author',
#                                                                                      OrderedDict([('id',
#                                                                                                    OrderedDict([('@type',
#                                                                                                                  'integer'),
#                                                                                                                 ('#text',
#                                                                                                                  '49585')])),
#                                                                                                   ('name',
#                                                                                                    'Mike Loukides')])),
# ...
#                                                                       ('original_publication_year',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('@nil',
#                                                                                      'true')])),
#                                                                       ('original_publication_month',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('@nil',
#                                                                                      'true')])),
#                                                                       ('original_publication_day',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('@nil',
#                                                                                      'true')])),
#                                                                       ('average_rating',
#                                                                        '3.50'),
#                                                                       ('best_book',
#                                                                        OrderedDict([('@type',
#                                                                                      'Book'),
#                                                                                     ('id',
#                                                                                      OrderedDict([('@type',
#                                                                                                    'integer'),
#                                                                                                   ('#text',
#                                                                                                    '27857550')])),
#                                                                                     ('title',
#                                                                                      'Python Data Science Cookbook'),
#                                                                                     ('author',
#                                                                                      OrderedDict([('id',
#                                                                                                    OrderedDict([('@type',
#                                                                                                                  'integer'),
#                                                                                                                 ('#text',
#                                                                                                                  '14683106')])),
#                                                                                                   ('name',
#                                                                                                    'Gopi Subramanian')])),
#                                                                                     ('image_url',
#                                                                                      'https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png'),
#                                                                                     ('small_image_url',
#                                                                                      'https://s.gr-assets.com/assets/nophoto/book/50x75-a91bf249278a81aabab721ef782c4a74.png')]))]),
#                                                          OrderedDict([('id',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '47774949')])),
#                                                                       ('books_count',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '4')])),
#                                                                       ('ratings_count',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '24')])),
#                                                                       ('text_reviews_count',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '5')])),
#                                                                       ('original_publication_year',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('@nil',
#                                                                                      'true')])),
#                                                                       ('original_publication_month',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('@nil',
#                                                                                      'true')])),
#                                                                       ('original_publication_day',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('@nil',
#                                                                                      'true')])),
#                                                                       ('average_rating',
#                                                                        '3.12'),
#                                                                       ('best_book',
#                                                                        OrderedDict([('@type',
#                                                                                      'Book'),
#                                                                                     ('id',
#                                                                                      OrderedDict([('@type',
#                                                                                                    'integer'),
#                                                                                                   ('#text',
#                                                                                                    '27797696')])),
#                                                                                     ('title',
#                                                                                      'Introducing Data Science'),
#                                                                                     ('author',
#                                                                                      OrderedDict([('id',
#                                                                                                    OrderedDict([('@type',
#                                                                                                                  'integer'),
#                                                                                                                 ('#text',
#                                                                                                                  '7042557')])),
#                                                                                                   ('name',
#                                                                                                    'Davy Cielen')])),
#                                                                                     ('image_url',
#                                                                                      'https://images.gr-assets.com/books/1447218033m/27797696.jpg'),
#                                                                                     ('small_image_url',
#                                                                                      'https://images.gr-assets.com/books/1447218033s/27797696.jpg')]))]),
#                                                          OrderedDict([('id',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '45658670')])),
#                                                                       ('books_count',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '4')])),
#                                                                       ('ratings_count',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '20')])),
#                                                                       ('text_reviews_count',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '2')])),
#                                                                       ('original_publication_year',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '2015')])),
#                                                                       ('original_publication_month',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '7')])),
#                                                                       ('original_publication_day',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '7')])),
#                                                                       ('average_rating',
#                                                                        '4.35'),
#                                                                       ('best_book',
#                                                                        OrderedDict([('@type',
#                                                                                      'Book'),
#                                                                                     ('id',
#                                                                                      OrderedDict([('@type',
#                                                                                                    'integer'),
#                                                                                                   ('#text',
#                                                                                                    '25804287')])),
#                                                                                     ('title',
#                                                                                      'Python for Data Science For Dummies (For Dummies)'),
#                                                                                     ('author',
#                                                                                      OrderedDict([('id',
#                                                                                                    OrderedDict([('@type',
#                                                                                                                  'integer'),
#                                                                                                                 ('#text',
#                                                                                                                  '163195')])),
#                                                                                                   ('name',
#                                                                                                    'John Paul Mueller')])),
#                                                                                     ('image_url',
#                                                                                      'https://images.gr-assets.com/books/1454837523m/25804287.jpg'),
#                                                                                     ('small_image_url',
#                                                                                      'https://images.gr-assets.com/books/1454837523s/25804287.jpg')]))])])]))]))]))])

# %%
type(results)
# Out:
# collections.OrderedDict

# %%
results.keys()
# Out:
# odict_keys(['GoodreadsResponse'])

# %%
results['GoodreadsResponse']
# Out:
# OrderedDict([('Request',
#               OrderedDict([('authentication', 'true'),
#                            ('key', 'ka4Fs642Xr9prKBGBraoSw'),
#                            ('method', 'search_index')])),
#              ('search',
#               OrderedDict([('query', 'data science'),
#                            ('results-start', '1'),
#                            ('results-end', '20'),
#                            ('total-results', '2114'),
#                            ('source', 'Goodreads'),
#                            ('query-time-seconds', '0.20'),
#                            ('results',
#                             OrderedDict([('work',
#                                           [OrderedDict([('id',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '24087179')])),
#                                                         ('books_count',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '9')])),
#                                                         ('ratings_count',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '436')])),
#                                                         ('text_reviews_count',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '43')])),
#                                                         ('original_publication_year',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '2013')])),
#                                                         ('original_publication_month',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '1')])),
#                                                         ('original_publication_day',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '1')])),
#                                                         ('average_rating',
#                                                          '3.74'),
#                                                         ('best_book',
#                                                          OrderedDict([('@type',
#                                                                        'Book'),
#                                                                       ('id',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '17346997')])),
#                                                                       ('title',
#                                                                        'Doing Data Science'),
#                                                                       ('author',
#                                                                        OrderedDict([('id',
#                                                                                      OrderedDict([('@type',
#                                                                                                    'integer'),
#                                                                                                   ('#text',
#                                                                                                    '5930481')])),
#                                                                                     ('name',
#                                                                                      'Rachel Schutt')])),
#                                                                       ('image_url',
#                                                                        'https://images.gr-assets.com/books/1411927798m/17346997.jpg'),
#                                                                       ('small_image_url',
#                                                                        'https://images.gr-assets.com/books/1411927798s/17346997.jpg')]))]),
#                                            OrderedDict([('id',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '24982572')])),
#                                                         ('books_count',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '9')])),
#                                                         ('ratings_count',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '752')])),
#                                                         ('text_reviews_count',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '44')])),
#                                                         ('original_publication_year',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '2013')])),
#                                                         ('original_publication_month',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '10')])),
#                                                         ('original_publication_day',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '31')])),
#                                                         ('average_rating',
#                                                          '4.17'),
#                                                         ('best_book',
#                                                          OrderedDict([('@type',
#                                                                        'Book'),
#                                                                       ('id',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '17682206')])),
#                                                                       ('title',
#                                                                        'Data Smart: Using Data Science to Transform Information into Insight'),
#                                                                       ('author',
#                                                                        OrderedDict([('id',
#                                                                                      OrderedDict([('@type',
#                                                                                                    'integer'),
#                                                                                                   ('#text',
#                                                                                                    '7445541')])),
#                                                                                     ('name',
#                                                                                      'John W. Foreman')])),
#                                                                       ('image_url',
#                                                                        'https://images.gr-assets.com/books/1540820090m/17682206.jpg'),
#                                                                       ('small_image_url',
#                                                                        'https://images.gr-assets.com/books/1540820090s/17682206.jpg')]))]),
#                                            OrderedDict([('id',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '45161385')])),
#                                                         ('books_count',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '11')])),
#                                                         ('ratings_count',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '541')])),
#                                                         ('text_reviews_count',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '45')])),
#                                                         ('original_publication_year',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '2015')])),
#                                                         ('original_publication_month',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '4')])),
#                                                         ('original_publication_day',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '14')])),
#                                                         ('average_rating',
#                                                          '3.91'),
#                                                         ('best_book',
#                                                          OrderedDict([('@type',
#                                                                        'Book'),
#                                                                       ('id',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '25407018')])),
#                                                                       ('title',
#                                                                        'Data Science from Scratch: First Principles with Python'),
#                                                                       ('author',
#                                                                        OrderedDict([('id',
#                                                                                      OrderedDict([('@type',
#                                                                                                    'integer'),
#                                                                                                   ('#text',
#                                                                                                    '2966563')])),
#                                                                                     ('name',
#                                                                                      'Joel Grus')])),
#                                                                       ('image_url',
#                                                                        'https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png'),
#                                                                       ('small_image_url',
#                                                                        'https://s.gr-assets.com/assets/nophoto/book/50x75-a91bf249278a81aabab721ef782c4a74.png')]))]),
#                                            OrderedDict([('id',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '44680072')])),
#                                                         ('books_count',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '12')])),
#                                                         ('ratings_count',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '108')])),
#                                                         ('text_reviews_count',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '11')])),
#                                                         ('original_publication_year',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '2014')])),
#                                                         ('original_publication_month',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '5')])),
#                                                         ('original_publication_day',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '19')])),
#                                                         ('average_rating',
#                                                          '3.42'),
#                                                         ('best_book',
#                                                          OrderedDict([('@type',
#                                                                        'Book'),
#                                                                       ('id',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '25008399')])),
#                                                                       ('title',
#                                                                        'Data Science For Dummies'),
#                                                                       ('author',
#                                                                        OrderedDict([('id',
#                                                                                      OrderedDict([('@type',
#                                                                                                    'integer'),
#                                                                                                   ('#text',
#                                                                                                    '8096344')])),
#                                                                                     ('name',
#                                                                                      'Lillian Pierson')])),
#                                                                       ('image_url',
#                                                                        'https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png'),
#                                                                       ('small_image_url',
#                                                                        'https://s.gr-assets.com/assets/nophoto/book/50x75-a91bf249278a81aabab721ef782c4a74.png')]))]),
#                                            OrderedDict([('id',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '58519365')])),
#                                                         ('books_count',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '4')])),
#                                                         ('ratings_count',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '114')])),
#                                                         ('text_reviews_count',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '14')])),
#                                                         ('original_publication_year',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('@nil',
#                                                                        'true')])),
#                                                         ('original_publication_month',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('@nil',
#                                                                        'true')])),
#                                                         ('original_publication_day',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('@nil',
#                                                                        'true')])),
#                                                         ('average_rating',
#                                                          '3.82'),
#                                                         ('best_book',
#                                                          OrderedDict([('@type',
#                                                                        'Book'),
#                                                                       ('id',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '36722689')])),
#                                                                       ('title',
#                                                                        'Data Science'),
#                                                                       ('author',
#                                                                        OrderedDict([('id',
#                                                                                      OrderedDict([('@type',
#                                                                                                    'integer'),
#                                                                                                   ('#text',
#                                                                                                    '1794190')])),
#                                                                                     ('name',
#                                                                                      'John D. Kelleher')])),
#                                                                       ('image_url',
#                                                                        'https://images.gr-assets.com/books/1514420265m/36722689.jpg'),
#                                                                       ('small_image_url',
#                                                                        'https://images.gr-assets.com/books/1514420265s/36722689.jpg')]))]),
#                                            OrderedDict([('id',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '17831806')])),
#                                                         ('books_count',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '5')])),
#                                                         ('ratings_count',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '259')])),
#                                                         ('text_reviews_count',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '12')])),
#                                                         ('original_publication_year',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '2011')])),
#                                                         ('original_publication_month',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '9')])),
#                                                         ('original_publication_day',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '15')])),
#                                                         ('average_rating',
#                                                          '3.65'),
#                                                         ('best_book',
#                                                          OrderedDict([('@type',
#                                                                        'Book'),
#                                                                       ('id',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '12700492')])),
#                                                                       ('title',
#                                                                        'Building Data Science Teams'),
#                                                                       ('author',
#                                                                        OrderedDict([('id',
#                                                                                      OrderedDict([('@type',
#                                                                                                    'integer'),
#                                                                                                   ('#text',
#                                                                                                    '5227216')])),
#                                                                                     ('name',
#                                                                                      'D.J. Patil')])),
#                                                                       ('image_url',
#                                                                        'https://images.gr-assets.com/books/1354249859m/12700492.jpg'),
#                                                                       ('small_image_url',
#                                                                        'https://images.gr-assets.com/books/1354249859s/12700492.jpg')]))]),
#                                            OrderedDict([('id',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '25100684')])),
#                                                         ('books_count',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '10')])),
#                                                         ('ratings_count',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '1292')])),
#                                                         ('text_reviews_count',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '86')])),
#                                                         ('original_publication_year',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '2013')])),
#                                                         ('original_publication_month',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '1')])),
#                                                         ('original_publication_day',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '1')])),
#                                                         ('average_rating',
#                                                          '4.17'),
#                                                         ('best_book',
#                                                          OrderedDict([('@type',
#                                                                        'Book'),
#                                                                       ('id',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '17912916')])),
#                                                                       ('title',
#                                                                        'Data Science for Business: What you need to know about data mining and data-analytic thinking'),
#                                                                       ('author',
#                                                                        OrderedDict([('id',
#                                                                                      OrderedDict([('@type',
#                                                                                                    'integer'),
#                                                                                                   ('#text',
#                                                                                                    '891152')])),
#                                                                                     ('name',
#                                                                                      'Foster Provost')])),
#                                                                       ('image_url',
#                                                                        'https://images.gr-assets.com/books/1374654260m/17912916.jpg'),
#                                                                       ('small_image_url',
#                                                                        'https://images.gr-assets.com/books/1374654260s/17912916.jpg')]))]),
#                                            OrderedDict([('id',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '19251618')])),
#                                                         ('books_count',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '7')])),
#                                                         ('ratings_count',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '471')])),
#                                                         ('text_reviews_count',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '30')])),
#                                                         ('original_publication_year',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '2011')])),
#                                                         ('original_publication_month',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '4')])),
#                                                         ('original_publication_day',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '1')])),
#                                                         ('average_rating',
#                                                          '3.66'),
#                                                         ('best_book',
#                                                          OrderedDict([('@type',
#                                                                        'Book'),
#                                                                       ('id',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '13638556')])),
#                                                                       ('title',
#                                                                        'What Is Data Science?'),
#                                                                       ('author',
#                                                                        OrderedDict([('id',
#                                                                                      OrderedDict([('@type',
#                                                                                                    'integer'),
#                                                                                                   ('#text',
#                                                                                                    '49585')])),
#                                                                                     ('name',
#                                                                                      'Mike Loukides')])),
#                                                                       ('image_url',
#                                                                        'https://images.gr-assets.com/books/1354251695m/13638556.jpg'),
#                                                                       ('small_image_url',
#                                                                        'https://images.gr-assets.com/books/1354251695s/13638556.jpg')]))]),
#                                            OrderedDict([('id',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '45100553')])),
#                                                         ('books_count',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '3')])),
#                                                         ('ratings_count',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '120')])),
#                                                         ('text_reviews_count',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '19')])),
#                                                         ('original_publication_year',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '2015')])),
#                                                         ('original_publication_month',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '4')])),
#                                                         ('original_publication_day',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '13')])),
#                                                         ('average_rating',
#                                                          '3.63'),
#                                                         ('best_book',
#                                                          OrderedDict([('@type',
#                                                                        'Book'),
#                                                                       ('id',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '25358081')])),
#                                                                       ('title',
#                                                                        'R Programming for Data Science'),
#                                                                       ('author',
#                                                                        OrderedDict([('id',
#                                                                                      OrderedDict([('@type',
#                                                                                                    'integer'),
#                                                                                                   ('#text',
#                                                                                                    '1580866')])),
#                                                                                     ('name',
#                                                                                      'Roger D. Peng')])),
#                                                                       ('image_url',
#                                                                        'https://images.gr-assets.com/books/1429019920m/25358081.jpg'),
#                                                                       ('small_image_url',
#                                                                        'https://images.gr-assets.com/books/1429019920s/25358081.jpg')]))]),
#                                            OrderedDict([('id',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '55261521')])),
#                                                         ('books_count',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '3')])),
#                                                         ('ratings_count',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '259')])),
# ...
#                                                                                      'Steven Skiena')])),
#                                                                       ('image_url',
#                                                                        'https://images.gr-assets.com/books/1519035542m/34266283.jpg'),
#                                                                       ('small_image_url',
#                                                                        'https://images.gr-assets.com/books/1519035542s/34266283.jpg')]))]),
#                                            OrderedDict([('id',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '47845573')])),
#                                                         ('books_count',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '5')])),
#                                                         ('ratings_count',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '10')])),
#                                                         ('text_reviews_count',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '1')])),
#                                                         ('original_publication_year',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('@nil',
#                                                                        'true')])),
#                                                         ('original_publication_month',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('@nil',
#                                                                        'true')])),
#                                                         ('original_publication_day',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('@nil',
#                                                                        'true')])),
#                                                         ('average_rating',
#                                                          '3.50'),
#                                                         ('best_book',
#                                                          OrderedDict([('@type',
#                                                                        'Book'),
#                                                                       ('id',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '27857550')])),
#                                                                       ('title',
#                                                                        'Python Data Science Cookbook'),
#                                                                       ('author',
#                                                                        OrderedDict([('id',
#                                                                                      OrderedDict([('@type',
#                                                                                                    'integer'),
#                                                                                                   ('#text',
#                                                                                                    '14683106')])),
#                                                                                     ('name',
#                                                                                      'Gopi Subramanian')])),
#                                                                       ('image_url',
#                                                                        'https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png'),
#                                                                       ('small_image_url',
#                                                                        'https://s.gr-assets.com/assets/nophoto/book/50x75-a91bf249278a81aabab721ef782c4a74.png')]))]),
#                                            OrderedDict([('id',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '47774949')])),
#                                                         ('books_count',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '4')])),
#                                                         ('ratings_count',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '24')])),
#                                                         ('text_reviews_count',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '5')])),
#                                                         ('original_publication_year',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('@nil',
#                                                                        'true')])),
#                                                         ('original_publication_month',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('@nil',
#                                                                        'true')])),
#                                                         ('original_publication_day',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('@nil',
#                                                                        'true')])),
#                                                         ('average_rating',
#                                                          '3.12'),
#                                                         ('best_book',
#                                                          OrderedDict([('@type',
#                                                                        'Book'),
#                                                                       ('id',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '27797696')])),
#                                                                       ('title',
#                                                                        'Introducing Data Science'),
#                                                                       ('author',
#                                                                        OrderedDict([('id',
#                                                                                      OrderedDict([('@type',
#                                                                                                    'integer'),
#                                                                                                   ('#text',
#                                                                                                    '7042557')])),
#                                                                                     ('name',
#                                                                                      'Davy Cielen')])),
#                                                                       ('image_url',
#                                                                        'https://images.gr-assets.com/books/1447218033m/27797696.jpg'),
#                                                                       ('small_image_url',
#                                                                        'https://images.gr-assets.com/books/1447218033s/27797696.jpg')]))]),
#                                            OrderedDict([('id',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '45658670')])),
#                                                         ('books_count',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '4')])),
#                                                         ('ratings_count',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '20')])),
#                                                         ('text_reviews_count',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '2')])),
#                                                         ('original_publication_year',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '2015')])),
#                                                         ('original_publication_month',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '7')])),
#                                                         ('original_publication_day',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '7')])),
#                                                         ('average_rating',
#                                                          '4.35'),
#                                                         ('best_book',
#                                                          OrderedDict([('@type',
#                                                                        'Book'),
#                                                                       ('id',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '25804287')])),
#                                                                       ('title',
#                                                                        'Python for Data Science For Dummies (For Dummies)'),
#                                                                       ('author',
#                                                                        OrderedDict([('id',
#                                                                                      OrderedDict([('@type',
#                                                                                                    'integer'),
#                                                                                                   ('#text',
#                                                                                                    '163195')])),
#                                                                                     ('name',
#                                                                                      'John Paul Mueller')])),
#                                                                       ('image_url',
#                                                                        'https://images.gr-assets.com/books/1454837523m/25804287.jpg'),
#                                                                       ('small_image_url',
#                                                                        'https://images.gr-assets.com/books/1454837523s/25804287.jpg')]))])])]))]))])

# %%
results['GoodreadsResponse'].keys()
# Out:
# odict_keys(['Request', 'search'])

# %%
results['GoodreadsResponse']['search']
# Out:
# OrderedDict([('query', 'data science'),
#              ('results-start', '1'),
#              ('results-end', '20'),
#              ('total-results', '2114'),
#              ('source', 'Goodreads'),
#              ('query-time-seconds', '0.20'),
#              ('results',
#               OrderedDict([('work',
#                             [OrderedDict([('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '24087179')])),
#                                           ('books_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '9')])),
#                                           ('ratings_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '436')])),
#                                           ('text_reviews_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '43')])),
#                                           ('original_publication_year',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '2013')])),
#                                           ('original_publication_month',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '1')])),
#                                           ('original_publication_day',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '1')])),
#                                           ('average_rating', '3.74'),
#                                           ('best_book',
#                                            OrderedDict([('@type', 'Book'),
#                                                         ('id',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '17346997')])),
#                                                         ('title',
#                                                          'Doing Data Science'),
#                                                         ('author',
#                                                          OrderedDict([('id',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '5930481')])),
#                                                                       ('name',
#                                                                        'Rachel Schutt')])),
#                                                         ('image_url',
#                                                          'https://images.gr-assets.com/books/1411927798m/17346997.jpg'),
#                                                         ('small_image_url',
#                                                          'https://images.gr-assets.com/books/1411927798s/17346997.jpg')]))]),
#                              OrderedDict([('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '24982572')])),
#                                           ('books_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '9')])),
#                                           ('ratings_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '752')])),
#                                           ('text_reviews_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '44')])),
#                                           ('original_publication_year',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '2013')])),
#                                           ('original_publication_month',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '10')])),
#                                           ('original_publication_day',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '31')])),
#                                           ('average_rating', '4.17'),
#                                           ('best_book',
#                                            OrderedDict([('@type', 'Book'),
#                                                         ('id',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '17682206')])),
#                                                         ('title',
#                                                          'Data Smart: Using Data Science to Transform Information into Insight'),
#                                                         ('author',
#                                                          OrderedDict([('id',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '7445541')])),
#                                                                       ('name',
#                                                                        'John W. Foreman')])),
#                                                         ('image_url',
#                                                          'https://images.gr-assets.com/books/1540820090m/17682206.jpg'),
#                                                         ('small_image_url',
#                                                          'https://images.gr-assets.com/books/1540820090s/17682206.jpg')]))]),
#                              OrderedDict([('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '45161385')])),
#                                           ('books_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '11')])),
#                                           ('ratings_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '541')])),
#                                           ('text_reviews_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '45')])),
#                                           ('original_publication_year',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '2015')])),
#                                           ('original_publication_month',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '4')])),
#                                           ('original_publication_day',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '14')])),
#                                           ('average_rating', '3.91'),
#                                           ('best_book',
#                                            OrderedDict([('@type', 'Book'),
#                                                         ('id',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '25407018')])),
#                                                         ('title',
#                                                          'Data Science from Scratch: First Principles with Python'),
#                                                         ('author',
#                                                          OrderedDict([('id',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '2966563')])),
#                                                                       ('name',
#                                                                        'Joel Grus')])),
#                                                         ('image_url',
#                                                          'https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png'),
#                                                         ('small_image_url',
#                                                          'https://s.gr-assets.com/assets/nophoto/book/50x75-a91bf249278a81aabab721ef782c4a74.png')]))]),
#                              OrderedDict([('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '44680072')])),
#                                           ('books_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '12')])),
#                                           ('ratings_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '108')])),
#                                           ('text_reviews_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '11')])),
#                                           ('original_publication_year',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '2014')])),
#                                           ('original_publication_month',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '5')])),
#                                           ('original_publication_day',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '19')])),
#                                           ('average_rating', '3.42'),
#                                           ('best_book',
#                                            OrderedDict([('@type', 'Book'),
#                                                         ('id',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '25008399')])),
#                                                         ('title',
#                                                          'Data Science For Dummies'),
#                                                         ('author',
#                                                          OrderedDict([('id',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '8096344')])),
#                                                                       ('name',
#                                                                        'Lillian Pierson')])),
#                                                         ('image_url',
#                                                          'https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png'),
#                                                         ('small_image_url',
#                                                          'https://s.gr-assets.com/assets/nophoto/book/50x75-a91bf249278a81aabab721ef782c4a74.png')]))]),
#                              OrderedDict([('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '58519365')])),
#                                           ('books_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '4')])),
#                                           ('ratings_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '114')])),
#                                           ('text_reviews_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '14')])),
#                                           ('original_publication_year',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('@nil', 'true')])),
#                                           ('original_publication_month',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('@nil', 'true')])),
#                                           ('original_publication_day',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('@nil', 'true')])),
#                                           ('average_rating', '3.82'),
#                                           ('best_book',
#                                            OrderedDict([('@type', 'Book'),
#                                                         ('id',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '36722689')])),
#                                                         ('title',
#                                                          'Data Science'),
#                                                         ('author',
#                                                          OrderedDict([('id',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '1794190')])),
#                                                                       ('name',
#                                                                        'John D. Kelleher')])),
#                                                         ('image_url',
#                                                          'https://images.gr-assets.com/books/1514420265m/36722689.jpg'),
#                                                         ('small_image_url',
#                                                          'https://images.gr-assets.com/books/1514420265s/36722689.jpg')]))]),
#                              OrderedDict([('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '17831806')])),
#                                           ('books_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '5')])),
#                                           ('ratings_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '259')])),
#                                           ('text_reviews_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '12')])),
#                                           ('original_publication_year',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '2011')])),
#                                           ('original_publication_month',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '9')])),
#                                           ('original_publication_day',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '15')])),
#                                           ('average_rating', '3.65'),
#                                           ('best_book',
#                                            OrderedDict([('@type', 'Book'),
#                                                         ('id',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '12700492')])),
#                                                         ('title',
#                                                          'Building Data Science Teams'),
#                                                         ('author',
#                                                          OrderedDict([('id',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '5227216')])),
#                                                                       ('name',
#                                                                        'D.J. Patil')])),
#                                                         ('image_url',
#                                                          'https://images.gr-assets.com/books/1354249859m/12700492.jpg'),
#                                                         ('small_image_url',
#                                                          'https://images.gr-assets.com/books/1354249859s/12700492.jpg')]))]),
#                              OrderedDict([('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '25100684')])),
#                                           ('books_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '10')])),
#                                           ('ratings_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '1292')])),
#                                           ('text_reviews_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '86')])),
#                                           ('original_publication_year',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '2013')])),
#                                           ('original_publication_month',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '1')])),
#                                           ('original_publication_day',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '1')])),
#                                           ('average_rating', '4.17'),
#                                           ('best_book',
#                                            OrderedDict([('@type', 'Book'),
#                                                         ('id',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '17912916')])),
#                                                         ('title',
#                                                          'Data Science for Business: What you need to know about data mining and data-analytic thinking'),
#                                                         ('author',
#                                                          OrderedDict([('id',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '891152')])),
#                                                                       ('name',
#                                                                        'Foster Provost')])),
#                                                         ('image_url',
#                                                          'https://images.gr-assets.com/books/1374654260m/17912916.jpg'),
#                                                         ('small_image_url',
#                                                          'https://images.gr-assets.com/books/1374654260s/17912916.jpg')]))]),
#                              OrderedDict([('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '19251618')])),
#                                           ('books_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '7')])),
#                                           ('ratings_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '471')])),
#                                           ('text_reviews_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '30')])),
#                                           ('original_publication_year',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '2011')])),
#                                           ('original_publication_month',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '4')])),
#                                           ('original_publication_day',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '1')])),
#                                           ('average_rating', '3.66'),
#                                           ('best_book',
#                                            OrderedDict([('@type', 'Book'),
#                                                         ('id',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '13638556')])),
#                                                         ('title',
#                                                          'What Is Data Science?'),
#                                                         ('author',
#                                                          OrderedDict([('id',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '49585')])),
#                                                                       ('name',
#                                                                        'Mike Loukides')])),
#                                                         ('image_url',
#                                                          'https://images.gr-assets.com/books/1354251695m/13638556.jpg'),
#                                                         ('small_image_url',
#                                                          'https://images.gr-assets.com/books/1354251695s/13638556.jpg')]))]),
#                              OrderedDict([('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '45100553')])),
#                                           ('books_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '3')])),
#                                           ('ratings_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '120')])),
#                                           ('text_reviews_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '19')])),
#                                           ('original_publication_year',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '2015')])),
#                                           ('original_publication_month',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '4')])),
#                                           ('original_publication_day',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '13')])),
#                                           ('average_rating', '3.63'),
#                                           ('best_book',
#                                            OrderedDict([('@type', 'Book'),
#                                                         ('id',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '25358081')])),
#                                                         ('title',
#                                                          'R Programming for Data Science'),
#                                                         ('author',
#                                                          OrderedDict([('id',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '1580866')])),
#                                                                       ('name',
#                                                                        'Roger D. Peng')])),
#                                                         ('image_url',
#                                                          'https://images.gr-assets.com/books/1429019920m/25358081.jpg'),
#                                                         ('small_image_url',
#                                                          'https://images.gr-assets.com/books/1429019920s/25358081.jpg')]))]),
#                              OrderedDict([('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '55261521')])),
#                                           ('books_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '3')])),
#                                           ('ratings_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '259')])),
#                                           ('text_reviews_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '43')])),
#                                           ('original_publication_year',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('@nil', 'true')])),
#                                           ('original_publication_month',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('@nil', 'true')])),
#                                           ('original_publication_day',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('@nil', 'true')])),
#                                           ('average_rating', '4.23'),
#                                           ('best_book',
#                                            OrderedDict([('@type', 'Book'),
#                                                         ('id',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '34213247')])),
#                                                         ('title',
#                                                          'Numsense! Data Science for the Layman: No Math Added'),
#                                                         ('author',
#                                                          OrderedDict([('id',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '16424443')])),
#                                                                       ('name',
#                                                                        'Annalyn Ng')])),
#                                                         ('image_url',
#                                                          'https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png'),
#                                                         ('small_image_url',
#                                                          'https://s.gr-assets.com/assets/nophoto/book/50x75-a91bf249278a81aabab721ef782c4a74.png')]))]),
#                              OrderedDict([('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '46459730')])),
#                                           ('books_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '7')])),
#                                           ('ratings_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '159')])),
#                                           ('text_reviews_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '20')])),
#                                           ('original_publication_year',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '2016')])),
#                                           ('original_publication_month',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '3')])),
#                                           ('original_publication_day',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '25')])),
#                                           ('average_rating', '4.30'),
#                                           ('best_book',
#                                            OrderedDict([('@type', 'Book'),
#                                                         ('id',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '26457146')])),
#                                                         ('title',
#                                                          'Python Data Science Handbook: Tools and Techniques for Developers'),
#                                                         ('author',
#                                                          OrderedDict([('id',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '14318227')])),
#                                                                       ('name',
#                                                                        'Jake Vanderplas')])),
#                                                         ('image_url',
#                                                          'https://images.gr-assets.com/books/1481029785m/26457146.jpg'),
#                                                         ('small_image_url',
#                                                          'https://images.gr-assets.com/books/1481029785s/26457146.jpg')]))]),
#                              OrderedDict([('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '26679681')])),
#                                           ('books_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '2')])),
#                                           ('ratings_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '67')])),
#                                           ('text_reviews_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '7')])),
#                                           ('original_publication_year',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '2014')])),
#                                           ('original_publication_month',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '5')])),
#                                           ('original_publication_day',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '28')])),
#                                           ('average_rating', '4.12'),
#                                           ('best_book',
#                                            OrderedDict([('@type', 'Book'),
#                                                         ('id',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '18774683')])),
#                                                         ('title',
#                                                          'Practical Data Science with R'),
#                                                         ('author',
#                                                          OrderedDict([('id',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '7382005')])),
#                                                                       ('name',
#                                                                        'Nina Zumel')])),
#                                                         ('image_url',
#                                                          'https://images.gr-assets.com/books/1384382929m/18774683.jpg'),
#                                                         ('small_image_url',
#                                                          'https://images.gr-assets.com/books/1384382929s/18774683.jpg')]))]),
#                              OrderedDict([('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '54149357')])),
#                                           ('books_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '8')])),
#                                           ('ratings_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '330')])),
#                                           ('text_reviews_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '39')])),
#                                           ('original_publication_year',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('@nil', 'true')])),
#                                           ('original_publication_month',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('@nil', 'true')])),
#                                           ('original_publication_day',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('@nil', 'true')])),
#                                           ('average_rating', '4.61'),
#                                           ('best_book',
#                                            OrderedDict([('@type', 'Book'),
#                                                         ('id',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '33399049')])),
#                                                         ('title',
#                                                          'R for Data Science: Import, Tidy, Transform, Visualize, and Model Data'),
#                                                         ('author',
#                                                          OrderedDict([('id',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '3064393')])),
#                                                                       ('name',
#                                                                        'Hadley Wickham')])),
#                                                         ('image_url',
#                                                          'https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png'),
#                                                         ('small_image_url',
#                                                          'https://s.gr-assets.com/assets/nophoto/book/50x75-a91bf249278a81aabab721ef782c4a74.png')]))]),
#                              OrderedDict([('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '22410416')])),
#                                           ('books_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '2')])),
#                                           ('ratings_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '69')])),
#                                           ('text_reviews_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '7')])),
#                                           ('original_publication_year',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '2012')])),
#                                           ('original_publication_month',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '11')])),
#                                           ('original_publication_day',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '2')])),
#                                           ('average_rating', '3.43'),
#                                           ('best_book',
#                                            OrderedDict([('@type', 'Book'),
#                                                         ('id',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '16286023')])),
#                                                         ('title',
#                                                          'A Simple Introduction to Data Science'),
#                                                         ('author',
#                                                          OrderedDict([('id',
#                                                                        OrderedDict([('@type',
# ...
#                                           ('original_publication_day',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('@nil', 'true')])),
#                                           ('average_rating', '3.13'),
#                                           ('best_book',
#                                            OrderedDict([('@type', 'Book'),
#                                                         ('id',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '17914583')])),
#                                                         ('title',
#                                                          'An Introduction to Data Science'),
#                                                         ('author',
#                                                          OrderedDict([('id',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '755881')])),
#                                                                       ('name',
#                                                                        'Jeffrey M. Stanton')])),
#                                                         ('image_url',
#                                                          'https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png'),
#                                                         ('small_image_url',
#                                                          'https://s.gr-assets.com/assets/nophoto/book/50x75-a91bf249278a81aabab721ef782c4a74.png')]))]),
#                              OrderedDict([('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '55324057')])),
#                                           ('books_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '3')])),
#                                           ('ratings_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '12')])),
#                                           ('text_reviews_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '4')])),
#                                           ('original_publication_year',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('@nil', 'true')])),
#                                           ('original_publication_month',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('@nil', 'true')])),
#                                           ('original_publication_day',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('@nil', 'true')])),
#                                           ('average_rating', '4.58'),
#                                           ('best_book',
#                                            OrderedDict([('@type', 'Book'),
#                                                         ('id',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '34266283')])),
#                                                         ('title',
#                                                          'The Data Science Design Manual'),
#                                                         ('author',
#                                                          OrderedDict([('id',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '7701245')])),
#                                                                       ('name',
#                                                                        'Steven Skiena')])),
#                                                         ('image_url',
#                                                          'https://images.gr-assets.com/books/1519035542m/34266283.jpg'),
#                                                         ('small_image_url',
#                                                          'https://images.gr-assets.com/books/1519035542s/34266283.jpg')]))]),
#                              OrderedDict([('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '47845573')])),
#                                           ('books_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '5')])),
#                                           ('ratings_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '10')])),
#                                           ('text_reviews_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '1')])),
#                                           ('original_publication_year',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('@nil', 'true')])),
#                                           ('original_publication_month',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('@nil', 'true')])),
#                                           ('original_publication_day',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('@nil', 'true')])),
#                                           ('average_rating', '3.50'),
#                                           ('best_book',
#                                            OrderedDict([('@type', 'Book'),
#                                                         ('id',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '27857550')])),
#                                                         ('title',
#                                                          'Python Data Science Cookbook'),
#                                                         ('author',
#                                                          OrderedDict([('id',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '14683106')])),
#                                                                       ('name',
#                                                                        'Gopi Subramanian')])),
#                                                         ('image_url',
#                                                          'https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png'),
#                                                         ('small_image_url',
#                                                          'https://s.gr-assets.com/assets/nophoto/book/50x75-a91bf249278a81aabab721ef782c4a74.png')]))]),
#                              OrderedDict([('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '47774949')])),
#                                           ('books_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '4')])),
#                                           ('ratings_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '24')])),
#                                           ('text_reviews_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '5')])),
#                                           ('original_publication_year',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('@nil', 'true')])),
#                                           ('original_publication_month',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('@nil', 'true')])),
#                                           ('original_publication_day',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('@nil', 'true')])),
#                                           ('average_rating', '3.12'),
#                                           ('best_book',
#                                            OrderedDict([('@type', 'Book'),
#                                                         ('id',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '27797696')])),
#                                                         ('title',
#                                                          'Introducing Data Science'),
#                                                         ('author',
#                                                          OrderedDict([('id',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '7042557')])),
#                                                                       ('name',
#                                                                        'Davy Cielen')])),
#                                                         ('image_url',
#                                                          'https://images.gr-assets.com/books/1447218033m/27797696.jpg'),
#                                                         ('small_image_url',
#                                                          'https://images.gr-assets.com/books/1447218033s/27797696.jpg')]))]),
#                              OrderedDict([('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '45658670')])),
#                                           ('books_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '4')])),
#                                           ('ratings_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '20')])),
#                                           ('text_reviews_count',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '2')])),
#                                           ('original_publication_year',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '2015')])),
#                                           ('original_publication_month',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '7')])),
#                                           ('original_publication_day',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '7')])),
#                                           ('average_rating', '4.35'),
#                                           ('best_book',
#                                            OrderedDict([('@type', 'Book'),
#                                                         ('id',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '25804287')])),
#                                                         ('title',
#                                                          'Python for Data Science For Dummies (For Dummies)'),
#                                                         ('author',
#                                                          OrderedDict([('id',
#                                                                        OrderedDict([('@type',
#                                                                                      'integer'),
#                                                                                     ('#text',
#                                                                                      '163195')])),
#                                                                       ('name',
#                                                                        'John Paul Mueller')])),
#                                                         ('image_url',
#                                                          'https://images.gr-assets.com/books/1454837523m/25804287.jpg'),
#                                                         ('small_image_url',
#                                                          'https://images.gr-assets.com/books/1454837523s/25804287.jpg')]))])])]))])

# %%
results['GoodreadsResponse']['search'].keys()
# Out:
# odict_keys(['query', 'results-start', 'results-end', 'total-results', 'source', 'query-time-seconds', 'results'])

# %%
results['GoodreadsResponse']['search']['results']
# Out:
# OrderedDict([('work',
#               [OrderedDict([('id',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '24087179')])),
#                             ('books_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '9')])),
#                             ('ratings_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '436')])),
#                             ('text_reviews_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '43')])),
#                             ('original_publication_year',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '2013')])),
#                             ('original_publication_month',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '1')])),
#                             ('original_publication_day',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '1')])),
#                             ('average_rating', '3.74'),
#                             ('best_book',
#                              OrderedDict([('@type', 'Book'),
#                                           ('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '17346997')])),
#                                           ('title', 'Doing Data Science'),
#                                           ('author',
#                                            OrderedDict([('id',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '5930481')])),
#                                                         ('name',
#                                                          'Rachel Schutt')])),
#                                           ('image_url',
#                                            'https://images.gr-assets.com/books/1411927798m/17346997.jpg'),
#                                           ('small_image_url',
#                                            'https://images.gr-assets.com/books/1411927798s/17346997.jpg')]))]),
#                OrderedDict([('id',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '24982572')])),
#                             ('books_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '9')])),
#                             ('ratings_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '752')])),
#                             ('text_reviews_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '44')])),
#                             ('original_publication_year',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '2013')])),
#                             ('original_publication_month',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '10')])),
#                             ('original_publication_day',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '31')])),
#                             ('average_rating', '4.17'),
#                             ('best_book',
#                              OrderedDict([('@type', 'Book'),
#                                           ('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '17682206')])),
#                                           ('title',
#                                            'Data Smart: Using Data Science to Transform Information into Insight'),
#                                           ('author',
#                                            OrderedDict([('id',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '7445541')])),
#                                                         ('name',
#                                                          'John W. Foreman')])),
#                                           ('image_url',
#                                            'https://images.gr-assets.com/books/1540820090m/17682206.jpg'),
#                                           ('small_image_url',
#                                            'https://images.gr-assets.com/books/1540820090s/17682206.jpg')]))]),
#                OrderedDict([('id',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '45161385')])),
#                             ('books_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '11')])),
#                             ('ratings_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '541')])),
#                             ('text_reviews_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '45')])),
#                             ('original_publication_year',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '2015')])),
#                             ('original_publication_month',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '4')])),
#                             ('original_publication_day',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '14')])),
#                             ('average_rating', '3.91'),
#                             ('best_book',
#                              OrderedDict([('@type', 'Book'),
#                                           ('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '25407018')])),
#                                           ('title',
#                                            'Data Science from Scratch: First Principles with Python'),
#                                           ('author',
#                                            OrderedDict([('id',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '2966563')])),
#                                                         ('name',
#                                                          'Joel Grus')])),
#                                           ('image_url',
#                                            'https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png'),
#                                           ('small_image_url',
#                                            'https://s.gr-assets.com/assets/nophoto/book/50x75-a91bf249278a81aabab721ef782c4a74.png')]))]),
#                OrderedDict([('id',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '44680072')])),
#                             ('books_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '12')])),
#                             ('ratings_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '108')])),
#                             ('text_reviews_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '11')])),
#                             ('original_publication_year',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '2014')])),
#                             ('original_publication_month',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '5')])),
#                             ('original_publication_day',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '19')])),
#                             ('average_rating', '3.42'),
#                             ('best_book',
#                              OrderedDict([('@type', 'Book'),
#                                           ('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '25008399')])),
#                                           ('title',
#                                            'Data Science For Dummies'),
#                                           ('author',
#                                            OrderedDict([('id',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '8096344')])),
#                                                         ('name',
#                                                          'Lillian Pierson')])),
#                                           ('image_url',
#                                            'https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png'),
#                                           ('small_image_url',
#                                            'https://s.gr-assets.com/assets/nophoto/book/50x75-a91bf249278a81aabab721ef782c4a74.png')]))]),
#                OrderedDict([('id',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '58519365')])),
#                             ('books_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '4')])),
#                             ('ratings_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '114')])),
#                             ('text_reviews_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '14')])),
#                             ('original_publication_year',
#                              OrderedDict([('@type', 'integer'),
#                                           ('@nil', 'true')])),
#                             ('original_publication_month',
#                              OrderedDict([('@type', 'integer'),
#                                           ('@nil', 'true')])),
#                             ('original_publication_day',
#                              OrderedDict([('@type', 'integer'),
#                                           ('@nil', 'true')])),
#                             ('average_rating', '3.82'),
#                             ('best_book',
#                              OrderedDict([('@type', 'Book'),
#                                           ('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '36722689')])),
#                                           ('title', 'Data Science'),
#                                           ('author',
#                                            OrderedDict([('id',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '1794190')])),
#                                                         ('name',
#                                                          'John D. Kelleher')])),
#                                           ('image_url',
#                                            'https://images.gr-assets.com/books/1514420265m/36722689.jpg'),
#                                           ('small_image_url',
#                                            'https://images.gr-assets.com/books/1514420265s/36722689.jpg')]))]),
#                OrderedDict([('id',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '17831806')])),
#                             ('books_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '5')])),
#                             ('ratings_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '259')])),
#                             ('text_reviews_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '12')])),
#                             ('original_publication_year',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '2011')])),
#                             ('original_publication_month',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '9')])),
#                             ('original_publication_day',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '15')])),
#                             ('average_rating', '3.65'),
#                             ('best_book',
#                              OrderedDict([('@type', 'Book'),
#                                           ('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '12700492')])),
#                                           ('title',
#                                            'Building Data Science Teams'),
#                                           ('author',
#                                            OrderedDict([('id',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '5227216')])),
#                                                         ('name',
#                                                          'D.J. Patil')])),
#                                           ('image_url',
#                                            'https://images.gr-assets.com/books/1354249859m/12700492.jpg'),
#                                           ('small_image_url',
#                                            'https://images.gr-assets.com/books/1354249859s/12700492.jpg')]))]),
#                OrderedDict([('id',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '25100684')])),
#                             ('books_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '10')])),
#                             ('ratings_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '1292')])),
#                             ('text_reviews_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '86')])),
#                             ('original_publication_year',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '2013')])),
#                             ('original_publication_month',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '1')])),
#                             ('original_publication_day',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '1')])),
#                             ('average_rating', '4.17'),
#                             ('best_book',
#                              OrderedDict([('@type', 'Book'),
#                                           ('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '17912916')])),
#                                           ('title',
#                                            'Data Science for Business: What you need to know about data mining and data-analytic thinking'),
#                                           ('author',
#                                            OrderedDict([('id',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '891152')])),
#                                                         ('name',
#                                                          'Foster Provost')])),
#                                           ('image_url',
#                                            'https://images.gr-assets.com/books/1374654260m/17912916.jpg'),
#                                           ('small_image_url',
#                                            'https://images.gr-assets.com/books/1374654260s/17912916.jpg')]))]),
#                OrderedDict([('id',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '19251618')])),
#                             ('books_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '7')])),
#                             ('ratings_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '471')])),
#                             ('text_reviews_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '30')])),
#                             ('original_publication_year',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '2011')])),
#                             ('original_publication_month',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '4')])),
#                             ('original_publication_day',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '1')])),
#                             ('average_rating', '3.66'),
#                             ('best_book',
#                              OrderedDict([('@type', 'Book'),
#                                           ('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '13638556')])),
#                                           ('title', 'What Is Data Science?'),
#                                           ('author',
#                                            OrderedDict([('id',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '49585')])),
#                                                         ('name',
#                                                          'Mike Loukides')])),
#                                           ('image_url',
#                                            'https://images.gr-assets.com/books/1354251695m/13638556.jpg'),
#                                           ('small_image_url',
#                                            'https://images.gr-assets.com/books/1354251695s/13638556.jpg')]))]),
#                OrderedDict([('id',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '45100553')])),
#                             ('books_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '3')])),
#                             ('ratings_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '120')])),
#                             ('text_reviews_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '19')])),
#                             ('original_publication_year',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '2015')])),
#                             ('original_publication_month',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '4')])),
#                             ('original_publication_day',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '13')])),
#                             ('average_rating', '3.63'),
#                             ('best_book',
#                              OrderedDict([('@type', 'Book'),
#                                           ('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '25358081')])),
#                                           ('title',
#                                            'R Programming for Data Science'),
#                                           ('author',
#                                            OrderedDict([('id',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '1580866')])),
#                                                         ('name',
#                                                          'Roger D. Peng')])),
#                                           ('image_url',
#                                            'https://images.gr-assets.com/books/1429019920m/25358081.jpg'),
#                                           ('small_image_url',
#                                            'https://images.gr-assets.com/books/1429019920s/25358081.jpg')]))]),
#                OrderedDict([('id',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '55261521')])),
#                             ('books_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '3')])),
#                             ('ratings_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '259')])),
#                             ('text_reviews_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '43')])),
#                             ('original_publication_year',
#                              OrderedDict([('@type', 'integer'),
#                                           ('@nil', 'true')])),
#                             ('original_publication_month',
#                              OrderedDict([('@type', 'integer'),
#                                           ('@nil', 'true')])),
#                             ('original_publication_day',
#                              OrderedDict([('@type', 'integer'),
#                                           ('@nil', 'true')])),
#                             ('average_rating', '4.23'),
#                             ('best_book',
#                              OrderedDict([('@type', 'Book'),
#                                           ('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '34213247')])),
#                                           ('title',
#                                            'Numsense! Data Science for the Layman: No Math Added'),
#                                           ('author',
#                                            OrderedDict([('id',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '16424443')])),
#                                                         ('name',
#                                                          'Annalyn Ng')])),
#                                           ('image_url',
#                                            'https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png'),
#                                           ('small_image_url',
#                                            'https://s.gr-assets.com/assets/nophoto/book/50x75-a91bf249278a81aabab721ef782c4a74.png')]))]),
#                OrderedDict([('id',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '46459730')])),
#                             ('books_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '7')])),
#                             ('ratings_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '159')])),
#                             ('text_reviews_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '20')])),
#                             ('original_publication_year',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '2016')])),
#                             ('original_publication_month',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '3')])),
#                             ('original_publication_day',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '25')])),
#                             ('average_rating', '4.30'),
#                             ('best_book',
#                              OrderedDict([('@type', 'Book'),
#                                           ('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '26457146')])),
#                                           ('title',
#                                            'Python Data Science Handbook: Tools and Techniques for Developers'),
#                                           ('author',
#                                            OrderedDict([('id',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '14318227')])),
#                                                         ('name',
#                                                          'Jake Vanderplas')])),
#                                           ('image_url',
#                                            'https://images.gr-assets.com/books/1481029785m/26457146.jpg'),
#                                           ('small_image_url',
#                                            'https://images.gr-assets.com/books/1481029785s/26457146.jpg')]))]),
#                OrderedDict([('id',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '26679681')])),
#                             ('books_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '2')])),
#                             ('ratings_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '67')])),
#                             ('text_reviews_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '7')])),
#                             ('original_publication_year',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '2014')])),
#                             ('original_publication_month',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '5')])),
#                             ('original_publication_day',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '28')])),
#                             ('average_rating', '4.12'),
#                             ('best_book',
#                              OrderedDict([('@type', 'Book'),
#                                           ('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '18774683')])),
#                                           ('title',
#                                            'Practical Data Science with R'),
#                                           ('author',
#                                            OrderedDict([('id',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '7382005')])),
#                                                         ('name',
#                                                          'Nina Zumel')])),
#                                           ('image_url',
#                                            'https://images.gr-assets.com/books/1384382929m/18774683.jpg'),
#                                           ('small_image_url',
#                                            'https://images.gr-assets.com/books/1384382929s/18774683.jpg')]))]),
#                OrderedDict([('id',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '54149357')])),
#                             ('books_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '8')])),
#                             ('ratings_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '330')])),
#                             ('text_reviews_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '39')])),
#                             ('original_publication_year',
#                              OrderedDict([('@type', 'integer'),
#                                           ('@nil', 'true')])),
#                             ('original_publication_month',
#                              OrderedDict([('@type', 'integer'),
#                                           ('@nil', 'true')])),
#                             ('original_publication_day',
#                              OrderedDict([('@type', 'integer'),
#                                           ('@nil', 'true')])),
#                             ('average_rating', '4.61'),
#                             ('best_book',
#                              OrderedDict([('@type', 'Book'),
#                                           ('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '33399049')])),
#                                           ('title',
#                                            'R for Data Science: Import, Tidy, Transform, Visualize, and Model Data'),
#                                           ('author',
#                                            OrderedDict([('id',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '3064393')])),
#                                                         ('name',
#                                                          'Hadley Wickham')])),
#                                           ('image_url',
#                                            'https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png'),
#                                           ('small_image_url',
#                                            'https://s.gr-assets.com/assets/nophoto/book/50x75-a91bf249278a81aabab721ef782c4a74.png')]))]),
#                OrderedDict([('id',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '22410416')])),
#                             ('books_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '2')])),
#                             ('ratings_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '69')])),
#                             ('text_reviews_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '7')])),
#                             ('original_publication_year',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '2012')])),
#                             ('original_publication_month',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '11')])),
#                             ('original_publication_day',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '2')])),
#                             ('average_rating', '3.43'),
#                             ('best_book',
#                              OrderedDict([('@type', 'Book'),
#                                           ('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '16286023')])),
#                                           ('title',
#                                            'A Simple Introduction to Data Science'),
#                                           ('author',
#                                            OrderedDict([('id',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '1048042')])),
#                                                         ('name',
#                                                          'Lars Nielsen')])),
#                                           ('image_url',
#                                            'https://images.gr-assets.com/books/1356138023m/16286023.jpg'),
#                                           ('small_image_url',
#                                            'https://images.gr-assets.com/books/1356138023s/16286023.jpg')]))]),
#                OrderedDict([('id',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '42854157')])),
#                             ('books_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '4')])),
#                             ('ratings_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '33')])),
#                             ('text_reviews_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '6')])),
#                             ('original_publication_year',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '2014')])),
#                             ('original_publication_month',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '1')])),
#                             ('original_publication_day',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '1')])),
#                             ('average_rating', '3.91'),
#                             ('best_book',
#                              OrderedDict([('@type', 'Book'),
#                                           ('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '23297742')])),
#                                           ('title',
#                                            'Practical Data Science Cookbook'),
#                                           ('author',
#                                            OrderedDict([('id',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '8647126')])),
#                                                         ('name',
#                                                          'Tony Ojeda')])),
#                                           ('image_url',
#                                            'https://images.gr-assets.com/books/1412259816m/23297742.jpg'),
#                                           ('small_image_url',
#                                            'https://images.gr-assets.com/books/1412259816s/23297742.jpg')]))]),
#                OrderedDict([('id',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '21448111')])),
#                             ('books_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '2')])),
#                             ('ratings_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '23')])),
#                             ('text_reviews_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '5')])),
#                             ('original_publication_year',
#                              OrderedDict([('@type', 'integer'),
#                                           ('@nil', 'true')])),
#                             ('original_publication_month',
#                              OrderedDict([('@type', 'integer'),
#                                           ('@nil', 'true')])),
#                             ('original_publication_day',
#                              OrderedDict([('@type', 'integer'),
#                                           ('@nil', 'true')])),
#                             ('average_rating', '3.13'),
#                             ('best_book',
#                              OrderedDict([('@type', 'Book'),
#                                           ('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '17914583')])),
#                                           ('title',
#                                            'An Introduction to Data Science'),
#                                           ('author',
#                                            OrderedDict([('id',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '755881')])),
#                                                         ('name',
#                                                          'Jeffrey M. Stanton')])),
#                                           ('image_url',
#                                            'https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png'),
#                                           ('small_image_url',
#                                            'https://s.gr-assets.com/assets/nophoto/book/50x75-a91bf249278a81aabab721ef782c4a74.png')]))]),
#                OrderedDict([('id',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '55324057')])),
#                             ('books_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '3')])),
#                             ('ratings_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '12')])),
#                             ('text_reviews_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '4')])),
#                             ('original_publication_year',
#                              OrderedDict([('@type', 'integer'),
#                                           ('@nil', 'true')])),
#                             ('original_publication_month',
#                              OrderedDict([('@type', 'integer'),
#                                           ('@nil', 'true')])),
#                             ('original_publication_day',
#                              OrderedDict([('@type', 'integer'),
#                                           ('@nil', 'true')])),
#                             ('average_rating', '4.58'),
#                             ('best_book',
#                              OrderedDict([('@type', 'Book'),
#                                           ('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '34266283')])),
#                                           ('title',
#                                            'The Data Science Design Manual'),
#                                           ('author',
#                                            OrderedDict([('id',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '7701245')])),
#                                                         ('name',
#                                                          'Steven Skiena')])),
#                                           ('image_url',
#                                            'https://images.gr-assets.com/books/1519035542m/34266283.jpg'),
#                                           ('small_image_url',
#                                            'https://images.gr-assets.com/books/1519035542s/34266283.jpg')]))]),
#                OrderedDict([('id',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '47845573')])),
#                             ('books_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '5')])),
#                             ('ratings_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '10')])),
#                             ('text_reviews_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '1')])),
#                             ('original_publication_year',
#                              OrderedDict([('@type', 'integer'),
#                                           ('@nil', 'true')])),
#                             ('original_publication_month',
#                              OrderedDict([('@type', 'integer'),
#                                           ('@nil', 'true')])),
#                             ('original_publication_day',
#                              OrderedDict([('@type', 'integer'),
#                                           ('@nil', 'true')])),
#                             ('average_rating', '3.50'),
#                             ('best_book',
#                              OrderedDict([('@type', 'Book'),
#                                           ('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '27857550')])),
#                                           ('title',
#                                            'Python Data Science Cookbook'),
#                                           ('author',
#                                            OrderedDict([('id',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '14683106')])),
#                                                         ('name',
#                                                          'Gopi Subramanian')])),
#                                           ('image_url',
#                                            'https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png'),
#                                           ('small_image_url',
#                                            'https://s.gr-assets.com/assets/nophoto/book/50x75-a91bf249278a81aabab721ef782c4a74.png')]))]),
#                OrderedDict([('id',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '47774949')])),
#                             ('books_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '4')])),
#                             ('ratings_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '24')])),
#                             ('text_reviews_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '5')])),
#                             ('original_publication_year',
#                              OrderedDict([('@type', 'integer'),
#                                           ('@nil', 'true')])),
#                             ('original_publication_month',
#                              OrderedDict([('@type', 'integer'),
#                                           ('@nil', 'true')])),
#                             ('original_publication_day',
#                              OrderedDict([('@type', 'integer'),
#                                           ('@nil', 'true')])),
#                             ('average_rating', '3.12'),
#                             ('best_book',
#                              OrderedDict([('@type', 'Book'),
#                                           ('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '27797696')])),
#                                           ('title',
#                                            'Introducing Data Science'),
#                                           ('author',
#                                            OrderedDict([('id',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '7042557')])),
#                                                         ('name',
#                                                          'Davy Cielen')])),
#                                           ('image_url',
#                                            'https://images.gr-assets.com/books/1447218033m/27797696.jpg'),
#                                           ('small_image_url',
#                                            'https://images.gr-assets.com/books/1447218033s/27797696.jpg')]))]),
#                OrderedDict([('id',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '45658670')])),
#                             ('books_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '4')])),
#                             ('ratings_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '20')])),
#                             ('text_reviews_count',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '2')])),
#                             ('original_publication_year',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '2015')])),
#                             ('original_publication_month',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '7')])),
#                             ('original_publication_day',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '7')])),
#                             ('average_rating', '4.35'),
#                             ('best_book',
#                              OrderedDict([('@type', 'Book'),
#                                           ('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '25804287')])),
#                                           ('title',
#                                            'Python for Data Science For Dummies (For Dummies)'),
#                                           ('author',
#                                            OrderedDict([('id',
#                                                          OrderedDict([('@type',
#                                                                        'integer'),
#                                                                       ('#text',
#                                                                        '163195')])),
#                                                         ('name',
#                                                          'John Paul Mueller')])),
#                                           ('image_url',
#                                            'https://images.gr-assets.com/books/1454837523m/25804287.jpg'),
#                                           ('small_image_url',
#                                            'https://images.gr-assets.com/books/1454837523s/25804287.jpg')]))])])])

# %%
results['GoodreadsResponse']['search']['results'].keys()
# Out:
# odict_keys(['work'])

# %%
results['GoodreadsResponse']['search']['results']['work']
# Out:
# [OrderedDict([('id',
#                OrderedDict([('@type', 'integer'), ('#text', '24087179')])),
#               ('books_count',
#                OrderedDict([('@type', 'integer'), ('#text', '9')])),
#               ('ratings_count',
#                OrderedDict([('@type', 'integer'), ('#text', '436')])),
#               ('text_reviews_count',
#                OrderedDict([('@type', 'integer'), ('#text', '43')])),
#               ('original_publication_year',
#                OrderedDict([('@type', 'integer'), ('#text', '2013')])),
#               ('original_publication_month',
#                OrderedDict([('@type', 'integer'), ('#text', '1')])),
#               ('original_publication_day',
#                OrderedDict([('@type', 'integer'), ('#text', '1')])),
#               ('average_rating', '3.74'),
#               ('best_book',
#                OrderedDict([('@type', 'Book'),
#                             ('id',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '17346997')])),
#                             ('title', 'Doing Data Science'),
#                             ('author',
#                              OrderedDict([('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '5930481')])),
#                                           ('name', 'Rachel Schutt')])),
#                             ('image_url',
#                              'https://images.gr-assets.com/books/1411927798m/17346997.jpg'),
#                             ('small_image_url',
#                              'https://images.gr-assets.com/books/1411927798s/17346997.jpg')]))]),
#  OrderedDict([('id',
#                OrderedDict([('@type', 'integer'), ('#text', '24982572')])),
#               ('books_count',
#                OrderedDict([('@type', 'integer'), ('#text', '9')])),
#               ('ratings_count',
#                OrderedDict([('@type', 'integer'), ('#text', '752')])),
#               ('text_reviews_count',
#                OrderedDict([('@type', 'integer'), ('#text', '44')])),
#               ('original_publication_year',
#                OrderedDict([('@type', 'integer'), ('#text', '2013')])),
#               ('original_publication_month',
#                OrderedDict([('@type', 'integer'), ('#text', '10')])),
#               ('original_publication_day',
#                OrderedDict([('@type', 'integer'), ('#text', '31')])),
#               ('average_rating', '4.17'),
#               ('best_book',
#                OrderedDict([('@type', 'Book'),
#                             ('id',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '17682206')])),
#                             ('title',
#                              'Data Smart: Using Data Science to Transform Information into Insight'),
#                             ('author',
#                              OrderedDict([('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '7445541')])),
#                                           ('name', 'John W. Foreman')])),
#                             ('image_url',
#                              'https://images.gr-assets.com/books/1540820090m/17682206.jpg'),
#                             ('small_image_url',
#                              'https://images.gr-assets.com/books/1540820090s/17682206.jpg')]))]),
#  OrderedDict([('id',
#                OrderedDict([('@type', 'integer'), ('#text', '45161385')])),
#               ('books_count',
#                OrderedDict([('@type', 'integer'), ('#text', '11')])),
#               ('ratings_count',
#                OrderedDict([('@type', 'integer'), ('#text', '541')])),
#               ('text_reviews_count',
#                OrderedDict([('@type', 'integer'), ('#text', '45')])),
#               ('original_publication_year',
#                OrderedDict([('@type', 'integer'), ('#text', '2015')])),
#               ('original_publication_month',
#                OrderedDict([('@type', 'integer'), ('#text', '4')])),
#               ('original_publication_day',
#                OrderedDict([('@type', 'integer'), ('#text', '14')])),
#               ('average_rating', '3.91'),
#               ('best_book',
#                OrderedDict([('@type', 'Book'),
#                             ('id',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '25407018')])),
#                             ('title',
#                              'Data Science from Scratch: First Principles with Python'),
#                             ('author',
#                              OrderedDict([('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '2966563')])),
#                                           ('name', 'Joel Grus')])),
#                             ('image_url',
#                              'https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png'),
#                             ('small_image_url',
#                              'https://s.gr-assets.com/assets/nophoto/book/50x75-a91bf249278a81aabab721ef782c4a74.png')]))]),
#  OrderedDict([('id',
#                OrderedDict([('@type', 'integer'), ('#text', '44680072')])),
#               ('books_count',
#                OrderedDict([('@type', 'integer'), ('#text', '12')])),
#               ('ratings_count',
#                OrderedDict([('@type', 'integer'), ('#text', '108')])),
#               ('text_reviews_count',
#                OrderedDict([('@type', 'integer'), ('#text', '11')])),
#               ('original_publication_year',
#                OrderedDict([('@type', 'integer'), ('#text', '2014')])),
#               ('original_publication_month',
#                OrderedDict([('@type', 'integer'), ('#text', '5')])),
#               ('original_publication_day',
#                OrderedDict([('@type', 'integer'), ('#text', '19')])),
#               ('average_rating', '3.42'),
#               ('best_book',
#                OrderedDict([('@type', 'Book'),
#                             ('id',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '25008399')])),
#                             ('title', 'Data Science For Dummies'),
#                             ('author',
#                              OrderedDict([('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '8096344')])),
#                                           ('name', 'Lillian Pierson')])),
#                             ('image_url',
#                              'https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png'),
#                             ('small_image_url',
#                              'https://s.gr-assets.com/assets/nophoto/book/50x75-a91bf249278a81aabab721ef782c4a74.png')]))]),
#  OrderedDict([('id',
#                OrderedDict([('@type', 'integer'), ('#text', '58519365')])),
#               ('books_count',
#                OrderedDict([('@type', 'integer'), ('#text', '4')])),
#               ('ratings_count',
#                OrderedDict([('@type', 'integer'), ('#text', '114')])),
#               ('text_reviews_count',
#                OrderedDict([('@type', 'integer'), ('#text', '14')])),
#               ('original_publication_year',
#                OrderedDict([('@type', 'integer'), ('@nil', 'true')])),
#               ('original_publication_month',
#                OrderedDict([('@type', 'integer'), ('@nil', 'true')])),
#               ('original_publication_day',
#                OrderedDict([('@type', 'integer'), ('@nil', 'true')])),
#               ('average_rating', '3.82'),
#               ('best_book',
#                OrderedDict([('@type', 'Book'),
#                             ('id',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '36722689')])),
#                             ('title', 'Data Science'),
#                             ('author',
#                              OrderedDict([('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '1794190')])),
#                                           ('name', 'John D. Kelleher')])),
#                             ('image_url',
#                              'https://images.gr-assets.com/books/1514420265m/36722689.jpg'),
#                             ('small_image_url',
#                              'https://images.gr-assets.com/books/1514420265s/36722689.jpg')]))]),
#  OrderedDict([('id',
#                OrderedDict([('@type', 'integer'), ('#text', '17831806')])),
#               ('books_count',
#                OrderedDict([('@type', 'integer'), ('#text', '5')])),
#               ('ratings_count',
#                OrderedDict([('@type', 'integer'), ('#text', '259')])),
#               ('text_reviews_count',
#                OrderedDict([('@type', 'integer'), ('#text', '12')])),
#               ('original_publication_year',
#                OrderedDict([('@type', 'integer'), ('#text', '2011')])),
#               ('original_publication_month',
#                OrderedDict([('@type', 'integer'), ('#text', '9')])),
#               ('original_publication_day',
#                OrderedDict([('@type', 'integer'), ('#text', '15')])),
#               ('average_rating', '3.65'),
#               ('best_book',
#                OrderedDict([('@type', 'Book'),
#                             ('id',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '12700492')])),
#                             ('title', 'Building Data Science Teams'),
#                             ('author',
#                              OrderedDict([('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '5227216')])),
#                                           ('name', 'D.J. Patil')])),
#                             ('image_url',
#                              'https://images.gr-assets.com/books/1354249859m/12700492.jpg'),
#                             ('small_image_url',
#                              'https://images.gr-assets.com/books/1354249859s/12700492.jpg')]))]),
#  OrderedDict([('id',
#                OrderedDict([('@type', 'integer'), ('#text', '25100684')])),
#               ('books_count',
#                OrderedDict([('@type', 'integer'), ('#text', '10')])),
#               ('ratings_count',
#                OrderedDict([('@type', 'integer'), ('#text', '1292')])),
#               ('text_reviews_count',
#                OrderedDict([('@type', 'integer'), ('#text', '86')])),
#               ('original_publication_year',
#                OrderedDict([('@type', 'integer'), ('#text', '2013')])),
#               ('original_publication_month',
#                OrderedDict([('@type', 'integer'), ('#text', '1')])),
#               ('original_publication_day',
#                OrderedDict([('@type', 'integer'), ('#text', '1')])),
#               ('average_rating', '4.17'),
#               ('best_book',
#                OrderedDict([('@type', 'Book'),
#                             ('id',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '17912916')])),
#                             ('title',
#                              'Data Science for Business: What you need to know about data mining and data-analytic thinking'),
#                             ('author',
#                              OrderedDict([('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '891152')])),
#                                           ('name', 'Foster Provost')])),
#                             ('image_url',
#                              'https://images.gr-assets.com/books/1374654260m/17912916.jpg'),
#                             ('small_image_url',
#                              'https://images.gr-assets.com/books/1374654260s/17912916.jpg')]))]),
#  OrderedDict([('id',
#                OrderedDict([('@type', 'integer'), ('#text', '19251618')])),
#               ('books_count',
#                OrderedDict([('@type', 'integer'), ('#text', '7')])),
#               ('ratings_count',
#                OrderedDict([('@type', 'integer'), ('#text', '471')])),
#               ('text_reviews_count',
#                OrderedDict([('@type', 'integer'), ('#text', '30')])),
#               ('original_publication_year',
#                OrderedDict([('@type', 'integer'), ('#text', '2011')])),
#               ('original_publication_month',
#                OrderedDict([('@type', 'integer'), ('#text', '4')])),
#               ('original_publication_day',
#                OrderedDict([('@type', 'integer'), ('#text', '1')])),
#               ('average_rating', '3.66'),
#               ('best_book',
#                OrderedDict([('@type', 'Book'),
#                             ('id',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '13638556')])),
#                             ('title', 'What Is Data Science?'),
#                             ('author',
#                              OrderedDict([('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '49585')])),
#                                           ('name', 'Mike Loukides')])),
#                             ('image_url',
#                              'https://images.gr-assets.com/books/1354251695m/13638556.jpg'),
#                             ('small_image_url',
#                              'https://images.gr-assets.com/books/1354251695s/13638556.jpg')]))]),
#  OrderedDict([('id',
#                OrderedDict([('@type', 'integer'), ('#text', '45100553')])),
#               ('books_count',
#                OrderedDict([('@type', 'integer'), ('#text', '3')])),
#               ('ratings_count',
#                OrderedDict([('@type', 'integer'), ('#text', '120')])),
#               ('text_reviews_count',
#                OrderedDict([('@type', 'integer'), ('#text', '19')])),
#               ('original_publication_year',
#                OrderedDict([('@type', 'integer'), ('#text', '2015')])),
#               ('original_publication_month',
#                OrderedDict([('@type', 'integer'), ('#text', '4')])),
#               ('original_publication_day',
#                OrderedDict([('@type', 'integer'), ('#text', '13')])),
#               ('average_rating', '3.63'),
#               ('best_book',
#                OrderedDict([('@type', 'Book'),
#                             ('id',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '25358081')])),
#                             ('title', 'R Programming for Data Science'),
#                             ('author',
#                              OrderedDict([('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '1580866')])),
#                                           ('name', 'Roger D. Peng')])),
#                             ('image_url',
#                              'https://images.gr-assets.com/books/1429019920m/25358081.jpg'),
#                             ('small_image_url',
#                              'https://images.gr-assets.com/books/1429019920s/25358081.jpg')]))]),
#  OrderedDict([('id',
#                OrderedDict([('@type', 'integer'), ('#text', '55261521')])),
#               ('books_count',
#                OrderedDict([('@type', 'integer'), ('#text', '3')])),
#               ('ratings_count',
#                OrderedDict([('@type', 'integer'), ('#text', '259')])),
#               ('text_reviews_count',
#                OrderedDict([('@type', 'integer'), ('#text', '43')])),
#               ('original_publication_year',
#                OrderedDict([('@type', 'integer'), ('@nil', 'true')])),
#               ('original_publication_month',
#                OrderedDict([('@type', 'integer'), ('@nil', 'true')])),
#               ('original_publication_day',
#                OrderedDict([('@type', 'integer'), ('@nil', 'true')])),
#               ('average_rating', '4.23'),
#               ('best_book',
#                OrderedDict([('@type', 'Book'),
#                             ('id',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '34213247')])),
#                             ('title',
#                              'Numsense! Data Science for the Layman: No Math Added'),
#                             ('author',
#                              OrderedDict([('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '16424443')])),
#                                           ('name', 'Annalyn Ng')])),
#                             ('image_url',
#                              'https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png'),
#                             ('small_image_url',
#                              'https://s.gr-assets.com/assets/nophoto/book/50x75-a91bf249278a81aabab721ef782c4a74.png')]))]),
#  OrderedDict([('id',
#                OrderedDict([('@type', 'integer'), ('#text', '46459730')])),
#               ('books_count',
#                OrderedDict([('@type', 'integer'), ('#text', '7')])),
#               ('ratings_count',
#                OrderedDict([('@type', 'integer'), ('#text', '159')])),
#               ('text_reviews_count',
#                OrderedDict([('@type', 'integer'), ('#text', '20')])),
#               ('original_publication_year',
#                OrderedDict([('@type', 'integer'), ('#text', '2016')])),
#               ('original_publication_month',
#                OrderedDict([('@type', 'integer'), ('#text', '3')])),
#               ('original_publication_day',
#                OrderedDict([('@type', 'integer'), ('#text', '25')])),
#               ('average_rating', '4.30'),
#               ('best_book',
#                OrderedDict([('@type', 'Book'),
#                             ('id',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '26457146')])),
#                             ('title',
#                              'Python Data Science Handbook: Tools and Techniques for Developers'),
#                             ('author',
#                              OrderedDict([('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '14318227')])),
#                                           ('name', 'Jake Vanderplas')])),
#                             ('image_url',
#                              'https://images.gr-assets.com/books/1481029785m/26457146.jpg'),
#                             ('small_image_url',
#                              'https://images.gr-assets.com/books/1481029785s/26457146.jpg')]))]),
#  OrderedDict([('id',
#                OrderedDict([('@type', 'integer'), ('#text', '26679681')])),
#               ('books_count',
#                OrderedDict([('@type', 'integer'), ('#text', '2')])),
#               ('ratings_count',
#                OrderedDict([('@type', 'integer'), ('#text', '67')])),
#               ('text_reviews_count',
#                OrderedDict([('@type', 'integer'), ('#text', '7')])),
#               ('original_publication_year',
#                OrderedDict([('@type', 'integer'), ('#text', '2014')])),
#               ('original_publication_month',
#                OrderedDict([('@type', 'integer'), ('#text', '5')])),
#               ('original_publication_day',
#                OrderedDict([('@type', 'integer'), ('#text', '28')])),
#               ('average_rating', '4.12'),
#               ('best_book',
#                OrderedDict([('@type', 'Book'),
#                             ('id',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '18774683')])),
#                             ('title', 'Practical Data Science with R'),
#                             ('author',
#                              OrderedDict([('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '7382005')])),
#                                           ('name', 'Nina Zumel')])),
#                             ('image_url',
#                              'https://images.gr-assets.com/books/1384382929m/18774683.jpg'),
#                             ('small_image_url',
#                              'https://images.gr-assets.com/books/1384382929s/18774683.jpg')]))]),
#  OrderedDict([('id',
#                OrderedDict([('@type', 'integer'), ('#text', '54149357')])),
#               ('books_count',
#                OrderedDict([('@type', 'integer'), ('#text', '8')])),
#               ('ratings_count',
#                OrderedDict([('@type', 'integer'), ('#text', '330')])),
#               ('text_reviews_count',
#                OrderedDict([('@type', 'integer'), ('#text', '39')])),
#               ('original_publication_year',
#                OrderedDict([('@type', 'integer'), ('@nil', 'true')])),
#               ('original_publication_month',
#                OrderedDict([('@type', 'integer'), ('@nil', 'true')])),
#               ('original_publication_day',
#                OrderedDict([('@type', 'integer'), ('@nil', 'true')])),
#               ('average_rating', '4.61'),
#               ('best_book',
#                OrderedDict([('@type', 'Book'),
#                             ('id',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '33399049')])),
#                             ('title',
#                              'R for Data Science: Import, Tidy, Transform, Visualize, and Model Data'),
#                             ('author',
#                              OrderedDict([('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '3064393')])),
#                                           ('name', 'Hadley Wickham')])),
#                             ('image_url',
#                              'https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png'),
#                             ('small_image_url',
#                              'https://s.gr-assets.com/assets/nophoto/book/50x75-a91bf249278a81aabab721ef782c4a74.png')]))]),
#  OrderedDict([('id',
#                OrderedDict([('@type', 'integer'), ('#text', '22410416')])),
#               ('books_count',
#                OrderedDict([('@type', 'integer'), ('#text', '2')])),
#               ('ratings_count',
#                OrderedDict([('@type', 'integer'), ('#text', '69')])),
#               ('text_reviews_count',
#                OrderedDict([('@type', 'integer'), ('#text', '7')])),
#               ('original_publication_year',
#                OrderedDict([('@type', 'integer'), ('#text', '2012')])),
#               ('original_publication_month',
#                OrderedDict([('@type', 'integer'), ('#text', '11')])),
#               ('original_publication_day',
#                OrderedDict([('@type', 'integer'), ('#text', '2')])),
#               ('average_rating', '3.43'),
#               ('best_book',
#                OrderedDict([('@type', 'Book'),
#                             ('id',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '16286023')])),
#                             ('title', 'A Simple Introduction to Data Science'),
#                             ('author',
#                              OrderedDict([('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '1048042')])),
#                                           ('name', 'Lars Nielsen')])),
#                             ('image_url',
#                              'https://images.gr-assets.com/books/1356138023m/16286023.jpg'),
#                             ('small_image_url',
#                              'https://images.gr-assets.com/books/1356138023s/16286023.jpg')]))]),
#  OrderedDict([('id',
#                OrderedDict([('@type', 'integer'), ('#text', '42854157')])),
#               ('books_count',
#                OrderedDict([('@type', 'integer'), ('#text', '4')])),
#               ('ratings_count',
#                OrderedDict([('@type', 'integer'), ('#text', '33')])),
#               ('text_reviews_count',
#                OrderedDict([('@type', 'integer'), ('#text', '6')])),
#               ('original_publication_year',
#                OrderedDict([('@type', 'integer'), ('#text', '2014')])),
#               ('original_publication_month',
#                OrderedDict([('@type', 'integer'), ('#text', '1')])),
#               ('original_publication_day',
#                OrderedDict([('@type', 'integer'), ('#text', '1')])),
#               ('average_rating', '3.91'),
#               ('best_book',
#                OrderedDict([('@type', 'Book'),
#                             ('id',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '23297742')])),
#                             ('title', 'Practical Data Science Cookbook'),
#                             ('author',
#                              OrderedDict([('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '8647126')])),
#                                           ('name', 'Tony Ojeda')])),
#                             ('image_url',
#                              'https://images.gr-assets.com/books/1412259816m/23297742.jpg'),
#                             ('small_image_url',
#                              'https://images.gr-assets.com/books/1412259816s/23297742.jpg')]))]),
#  OrderedDict([('id',
#                OrderedDict([('@type', 'integer'), ('#text', '21448111')])),
#               ('books_count',
#                OrderedDict([('@type', 'integer'), ('#text', '2')])),
#               ('ratings_count',
#                OrderedDict([('@type', 'integer'), ('#text', '23')])),
#               ('text_reviews_count',
#                OrderedDict([('@type', 'integer'), ('#text', '5')])),
#               ('original_publication_year',
#                OrderedDict([('@type', 'integer'), ('@nil', 'true')])),
#               ('original_publication_month',
#                OrderedDict([('@type', 'integer'), ('@nil', 'true')])),
#               ('original_publication_day',
#                OrderedDict([('@type', 'integer'), ('@nil', 'true')])),
#               ('average_rating', '3.13'),
#               ('best_book',
#                OrderedDict([('@type', 'Book'),
#                             ('id',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '17914583')])),
#                             ('title', 'An Introduction to Data Science'),
#                             ('author',
#                              OrderedDict([('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '755881')])),
#                                           ('name', 'Jeffrey M. Stanton')])),
#                             ('image_url',
#                              'https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png'),
#                             ('small_image_url',
#                              'https://s.gr-assets.com/assets/nophoto/book/50x75-a91bf249278a81aabab721ef782c4a74.png')]))]),
#  OrderedDict([('id',
#                OrderedDict([('@type', 'integer'), ('#text', '55324057')])),
#               ('books_count',
#                OrderedDict([('@type', 'integer'), ('#text', '3')])),
#               ('ratings_count',
#                OrderedDict([('@type', 'integer'), ('#text', '12')])),
#               ('text_reviews_count',
#                OrderedDict([('@type', 'integer'), ('#text', '4')])),
#               ('original_publication_year',
#                OrderedDict([('@type', 'integer'), ('@nil', 'true')])),
#               ('original_publication_month',
#                OrderedDict([('@type', 'integer'), ('@nil', 'true')])),
#               ('original_publication_day',
#                OrderedDict([('@type', 'integer'), ('@nil', 'true')])),
#               ('average_rating', '4.58'),
#               ('best_book',
#                OrderedDict([('@type', 'Book'),
#                             ('id',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '34266283')])),
#                             ('title', 'The Data Science Design Manual'),
#                             ('author',
#                              OrderedDict([('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '7701245')])),
#                                           ('name', 'Steven Skiena')])),
#                             ('image_url',
#                              'https://images.gr-assets.com/books/1519035542m/34266283.jpg'),
#                             ('small_image_url',
#                              'https://images.gr-assets.com/books/1519035542s/34266283.jpg')]))]),
#  OrderedDict([('id',
#                OrderedDict([('@type', 'integer'), ('#text', '47845573')])),
#               ('books_count',
#                OrderedDict([('@type', 'integer'), ('#text', '5')])),
#               ('ratings_count',
#                OrderedDict([('@type', 'integer'), ('#text', '10')])),
#               ('text_reviews_count',
#                OrderedDict([('@type', 'integer'), ('#text', '1')])),
#               ('original_publication_year',
#                OrderedDict([('@type', 'integer'), ('@nil', 'true')])),
#               ('original_publication_month',
#                OrderedDict([('@type', 'integer'), ('@nil', 'true')])),
#               ('original_publication_day',
#                OrderedDict([('@type', 'integer'), ('@nil', 'true')])),
#               ('average_rating', '3.50'),
#               ('best_book',
#                OrderedDict([('@type', 'Book'),
#                             ('id',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '27857550')])),
#                             ('title', 'Python Data Science Cookbook'),
#                             ('author',
#                              OrderedDict([('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '14683106')])),
#                                           ('name', 'Gopi Subramanian')])),
#                             ('image_url',
#                              'https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png'),
#                             ('small_image_url',
#                              'https://s.gr-assets.com/assets/nophoto/book/50x75-a91bf249278a81aabab721ef782c4a74.png')]))]),
#  OrderedDict([('id',
#                OrderedDict([('@type', 'integer'), ('#text', '47774949')])),
#               ('books_count',
#                OrderedDict([('@type', 'integer'), ('#text', '4')])),
#               ('ratings_count',
#                OrderedDict([('@type', 'integer'), ('#text', '24')])),
#               ('text_reviews_count',
#                OrderedDict([('@type', 'integer'), ('#text', '5')])),
#               ('original_publication_year',
#                OrderedDict([('@type', 'integer'), ('@nil', 'true')])),
#               ('original_publication_month',
#                OrderedDict([('@type', 'integer'), ('@nil', 'true')])),
#               ('original_publication_day',
#                OrderedDict([('@type', 'integer'), ('@nil', 'true')])),
#               ('average_rating', '3.12'),
#               ('best_book',
#                OrderedDict([('@type', 'Book'),
#                             ('id',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '27797696')])),
#                             ('title', 'Introducing Data Science'),
#                             ('author',
#                              OrderedDict([('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text',
#                                                          '7042557')])),
#                                           ('name', 'Davy Cielen')])),
#                             ('image_url',
#                              'https://images.gr-assets.com/books/1447218033m/27797696.jpg'),
#                             ('small_image_url',
#                              'https://images.gr-assets.com/books/1447218033s/27797696.jpg')]))]),
#  OrderedDict([('id',
#                OrderedDict([('@type', 'integer'), ('#text', '45658670')])),
#               ('books_count',
#                OrderedDict([('@type', 'integer'), ('#text', '4')])),
#               ('ratings_count',
#                OrderedDict([('@type', 'integer'), ('#text', '20')])),
#               ('text_reviews_count',
#                OrderedDict([('@type', 'integer'), ('#text', '2')])),
#               ('original_publication_year',
#                OrderedDict([('@type', 'integer'), ('#text', '2015')])),
#               ('original_publication_month',
#                OrderedDict([('@type', 'integer'), ('#text', '7')])),
#               ('original_publication_day',
#                OrderedDict([('@type', 'integer'), ('#text', '7')])),
#               ('average_rating', '4.35'),
#               ('best_book',
#                OrderedDict([('@type', 'Book'),
#                             ('id',
#                              OrderedDict([('@type', 'integer'),
#                                           ('#text', '25804287')])),
#                             ('title',
#                              'Python for Data Science For Dummies (For Dummies)'),
#                             ('author',
#                              OrderedDict([('id',
#                                            OrderedDict([('@type', 'integer'),
#                                                         ('#text', '163195')])),
#                                           ('name', 'John Paul Mueller')])),
#                             ('image_url',
#                              'https://images.gr-assets.com/books/1454837523m/25804287.jpg'),
#                             ('small_image_url',
#                              'https://images.gr-assets.com/books/1454837523s/25804287.jpg')]))])]

# %%
len(results['GoodreadsResponse']['search']['results']['work'])
# Out:
# 20

# %%
###You can see there are 20 books in this first page

# %%
results['GoodreadsResponse']['search']['results']['work'][0].keys()
# Out:
# odict_keys(['id', 'books_count', 'ratings_count', 'text_reviews_count', 'original_publication_year', 'original_publication_month', 'original_publication_day', 'average_rating', 'best_book'])

# %%
#details about the first book

results['GoodreadsResponse']['search']['results']['work'][0]['best_book']
# Out:
# OrderedDict([('@type', 'Book'),
#              ('id',
#               OrderedDict([('@type', 'integer'), ('#text', '17346997')])),
#              ('title', 'Doing Data Science'),
#              ('author',
#               OrderedDict([('id',
#                             OrderedDict([('@type', 'integer'),
#                                          ('#text', '5930481')])),
#                            ('name', 'Rachel Schutt')])),
#              ('image_url',
#               'https://images.gr-assets.com/books/1411927798m/17346997.jpg'),
#              ('small_image_url',
#               'https://images.gr-assets.com/books/1411927798s/17346997.jpg')])

# %%
results['GoodreadsResponse']['search']['results']['work'][0]['best_book'].keys()
# Out:
# odict_keys(['@type', 'id', 'title', 'author', 'image_url', 'small_image_url'])

# %%
title = results['GoodreadsResponse']['search']['results']['work'][0]['best_book']['title']

# %%
author = results['GoodreadsResponse']['search']['results']['work'][0]['best_book']['author']

# %%
page_len = len(results['GoodreadsResponse']['search']['results']['work'])
data_dict = {}
for book_idx in range(page_len):
    data_dict[book_idx] = {
        'book_id': results['GoodreadsResponse']['search']['results']['work'][0]['best_book']['id']['#text'],
        'book_author': results['GoodreadsResponse']['search']['results']['work'][book_idx]['best_book']['author']['name'],
        'book_title': results['GoodreadsResponse']['search']['results']['work'][book_idx]['best_book']['title'],
    }

# %%
import numpy as np
import pandas as pd

# %%
pd.DataFrame.from_dict(data_dict, orient='index')
# Out:
#      book_id         book_author  \
# 0   17346997       Rachel Schutt
# 1   17346997     John W. Foreman
# 2   17346997           Joel Grus
# 3   17346997     Lillian Pierson
# 4   17346997    John D. Kelleher
# 5   17346997          D.J. Patil
# 6   17346997      Foster Provost
# 7   17346997       Mike Loukides
# 8   17346997       Roger D. Peng
# 9   17346997          Annalyn Ng
# 10  17346997     Jake Vanderplas
# 11  17346997          Nina Zumel
# 12  17346997      Hadley Wickham
# 13  17346997        Lars Nielsen
# 14  17346997          Tony Ojeda
# 15  17346997  Jeffrey M. Stanton
# 16  17346997       Steven Skiena
# 17  17346997    Gopi Subramanian
# 18  17346997         Davy Cielen
# 19  17346997   John Paul Mueller
#
#                                            book_title
# 0                                  Doing Data Science
# 1   Data Smart: Using Data Science to Transform In...
# 2   Data Science from Scratch: First Principles wi...
# 3                            Data Science For Dummies
# 4                                        Data Science
# 5                         Building Data Science Teams
# 6   Data Science for Business: What you need to kn...
# 7                               What Is Data Science?
# 8                      R Programming for Data Science
# 9   Numsense! Data Science for the Layman: No Math...
# 10  Python Data Science Handbook: Tools and Techni...
# 11                      Practical Data Science with R
# 12  R for Data Science: Import, Tidy, Transform, V...
# 13              A Simple Introduction to Data Science
# 14                    Practical Data Science Cookbook
# 15                    An Introduction to Data Science
# 16                     The Data Science Design Manual
# 17                       Python Data Science Cookbook
# 18                           Introducing Data Science
# 19  Python for Data Science For Dummies (For Dummies)

# %% [markdown]
# Create a for loop to go through 39 pages of results and find all data science related books

# %%
#importing time tells python to stop for 1 second so we don't overload the server we are hitting


import time

base_url = 'https://www.goodreads.com/'
search_endpoint = 'search/index.xml'
parameters = {
    'q': 'data science',
    'page': 1,
    'key': keys['key']
}

data_dictionary = {}
current_id = 0

for request_num in range(1,40):
    print("Hey you! I'm on page {}".format(request_num))
    parameters['page'] = request_num
    time.sleep(1)
    r = requests.get(base_url + search_endpoint,params=parameters)
    if r.status_code != 200:
        print(r.status_code)
        break
    results = xmltodict.parse(r.text)
    books = results['GoodreadsResponse']['search']['results']['work']
    for book in books:
        data_dictionary[current_id] = {
            'book_id': book['best_book']['id']['#text'],
            'book_title':  book['best_book']['title'],
            'book_author': book['best_book']['author']['name']
        }
        current_id += 1
# Out:
# Hey you! I'm on page 1
# Hey you! I'm on page 2
# Hey you! I'm on page 3
# Hey you! I'm on page 4
# Hey you! I'm on page 5
# Hey you! I'm on page 6
# Hey you! I'm on page 7
# Hey you! I'm on page 8
# Hey you! I'm on page 9
# Hey you! I'm on page 10
# Hey you! I'm on page 11
# Hey you! I'm on page 12
# Hey you! I'm on page 13
# Hey you! I'm on page 14
# Hey you! I'm on page 15
# Hey you! I'm on page 16
# Hey you! I'm on page 17
# Hey you! I'm on page 18
# Hey you! I'm on page 19
# Hey you! I'm on page 20
# Hey you! I'm on page 21
# Hey you! I'm on page 22
# Hey you! I'm on page 23
# Hey you! I'm on page 24
# Hey you! I'm on page 25
# Hey you! I'm on page 26
# Hey you! I'm on page 27
# Hey you! I'm on page 28
# Hey you! I'm on page 29
# Hey you! I'm on page 30
# Hey you! I'm on page 31
# Hey you! I'm on page 32
# Hey you! I'm on page 33
# Hey you! I'm on page 34
# Hey you! I'm on page 35
# Hey you! I'm on page 36
# Hey you! I'm on page 37
# Hey you! I'm on page 38
# Hey you! I'm on page 39

# %%
pd.DataFrame.from_dict(data_dictionary, orient='index')
# Out:
#       book_id                                         book_title  \
# 0    17346997                                 Doing Data Science
# 1    17682206  Data Smart: Using Data Science to Transform In...
# 2    25407018  Data Science from Scratch: First Principles wi...
# 3    25008399                           Data Science For Dummies
# 4    36722689                                       Data Science
# 5    12700492                        Building Data Science Teams
# 6    17912916  Data Science for Business: What you need to kn...
# 7    13638556                              What Is Data Science?
# 8    25358081                     R Programming for Data Science
# 9    34213247  Numsense! Data Science for the Layman: No Math...
# 10   26457146  Python Data Science Handbook: Tools and Techni...
# 11   18774683                      Practical Data Science with R
# 12   33399049  R for Data Science: Import, Tidy, Transform, V...
# 13   16286023              A Simple Introduction to Data Science
# 14   23297742                    Practical Data Science Cookbook
# 15   17914583                    An Introduction to Data Science
# 16   34266283                     The Data Science Design Manual
# 17   27857550                       Python Data Science Cookbook
# 18   27797696                           Introducing Data Science
# 19   25804287  Python for Data Science For Dummies (For Dummies)
# 20   34461531                          The Data Science Handbook
# 21   39100061  Data Science from Scratch: Practical Guide wit...
# 22   26299386  The Art of Data Science: A Guide for Anyone Wh...
# 23   25527772  Python Data Science Essentials - Learn the fun...
# 24   18874082       How Data Science Is Transforming Health Care
# 25   30462852  Computer Age Statistical Inference: Algorithms...
# 26   25426657                        Foundations of Data Science
# 27   24335406  R for Data Science - R Data Science Tips, Solu...
# 28   22967424  Data Science at the Command Line: Facing the F...
# 29   15815177  Agile Data Science: Building Data Analytics Ap...
# ..        ...                                                ...
# 750  36335283                      Big Data in Cognitive Science
# 751   8930424  Bayesian Logical Data Analysis for the Physica...
# 752   1848922  Introduction to Computer Science: Programming,...
# 753  41080774  Haunted Data: Transmedia, Affect, Weird Scienc...
# 754  13747661  Research Methods and Data Analysis in the Soci...
# 755   1976503      Statistical Methods for Spatial Data Analysis
# 756   7039901       Data Mining Techniques for the Life Sciences
# 757   8267611       The Cambridge Handbook of Earth Science Data
# 758   3347251           Data Visualization: The State of the Art
# 759  25571709  Introduction to Data Technologies (Chapman & H...
# 760  35823505  Applied Survey Data Analysis (Chapman & Hall/C...
# 761  27125539  PHP: Programming, Master's Handbook: A True Be...
# 762  29872816  Javascript Programming Box Set: Programming, M...
# 763  29743460  Java Programming Box Set: Programming, Master'...
# 764  27125555  Java Programming: Master's Handbook: A True Be...
# 765  27125522  Python: Programming, Master's Handbook; A True...
# 766  41808382  Machine Learning for Beginners: Your Ultimate ...
# 767  29928372  Ruby Programming Box Set: Programming, Master'...
# 768  29580203  Swift: Programming, Master's Handbook; A True ...
# 769  27125562  Ruby: Programming, Master's Handbook: A True B...
# 770  25902134  Swift: Programming, Master's Handbook: A TRUE ...
# 771  43173249  Python Deep Learning from Basics: Fundamental ...
# 772  43340779  Machine Learning for Beginners: Your Ultimate ...
# 773   1738957  Bayes and Empirical Bayes Methods for Data Ana...
# 774   3666089  Introduction to Computer Science: Programming,...
# 775   5101829  Nuclear Data For Science And Technology: Proce...
# 776  26782069                        Art and Science of Big Data
# 777   6016363               Intelligent Data Analysis in Science
# 778  40791392  Advances in Computing and Data Sciences: First...
# 779     78688                     Data Discovery: Global Warming
#
#                    book_author
# 0                Rachel Schutt
# 1              John W. Foreman
# 2                    Joel Grus
# 3              Lillian Pierson
# 4             John D. Kelleher
# 5                   D.J. Patil
# 6               Foster Provost
# 7                Mike Loukides
# 8                Roger D. Peng
# 9                   Annalyn Ng
# 10             Jake Vanderplas
# 11                  Nina Zumel
# 12              Hadley Wickham
# 13                Lars Nielsen
# 14                  Tony Ojeda
# 15          Jeffrey M. Stanton
# 16               Steven Skiena
# 17            Gopi Subramanian
# 18                 Davy Cielen
# 19           John Paul Mueller
# 20                  Field Cady
# 21              Alain Kaufmann
# 22               Roger D. Peng
# 23           Alberto Boschetti
# 24               Mike Loukides
# 25               Bradley Efron
# 26                  Avrim Blum
# 27                  Dan Toomey
# 28             Jeroen Janssens
# 29              Russell Jurney
# ..                         ...
# 750           Michael N. Jones
# 751               Phil Gregory
# 752             Thomas L. Naps
# 753              Lisa Blackman
# 754              Thomas Herzog
# 755       Oliver Schabenberger
# 756            Oliviero Carugo
# 757             Paul Henderson
# 758              Frits H. Post
# 759               Paul Murrell
# 760         Steven G. Heeringa
# 761           Codewell Academy
# 762          Code Well Academy
# 763          Code Well Academy
# 764           Codewell Academy
# 765          Code Well Academy
# 766         Jonathan S. Walker
# 767          Code Well Academy
# 768          Code Well Academy
# 769           Codewell Academy
# 770          Code Well Academy
# 771            Prof John Smith
# 772          Jonathan S Walker
# 773          Bradley P. Carlin
# 774           Douglas W. Nance
# 775               Syed M. Qaim
# 776              Serge Miranda
# 777            Hugh Cartwright
# 778               Mayank Singh
# 779  Inc. Planet Earth Science
#
# [780 rows x 3 columns]
